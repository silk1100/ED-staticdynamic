# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from collections import defaultdict, Counter
from pathlib import Path
import joblib
import sys
from types import ModuleType, FunctionType
from gc import get_referents
# %matplotlib inline

# %%
main_dir = "/project/InternalMedicine/Basit_lab/s223850/ED-StaticDynamic/ml_results_240324/tr_8_te_4/run_1/"

# %%
static_dir = os.path.join(main_dir, 'static')
dynamic_dir = os.path.join(main_dir, 'dynamic')
comb_dir = os.path.join(main_dir, 'comb')
all_dir = os.path.join(main_dir, 'all')

# %%
with open(os.path.join(static_dir, 'static_results_62_0.joblib'), 'rb') as f:
    d = joblib.load(f)

# %%
df = pd.DataFrame(d['cat']['model'].feature_importances_, columns=['imp'])

# %%
df['names'] = d['cat']['model'].feature_names_

# %%
df.sort_values(by='imp', ascending=False).iloc[:10]['names'].tolist()
# Out:
# ['Acuity_Level',
#  'Number of past appointments in last 60 days',
#  'Means_Of_Arrival_Ambulance',
#  'Number of past inpatient admissions over ED visits in last three years',
#  'MOTORVEHICLECRASH',
#  'FirstRace_Black or African American',
#  'FirstRace_White',
#  'Unknown',
#  'BREATHINGPROBLEM',
#  'Means_Of_Arrival_Car']

# %%
BLACKLIST = type, ModuleType, FunctionType

def getsize(obj):
    """sum size of object & members."""
    if isinstance(obj, BLACKLIST):
        raise TypeError('getsize() does not take argument of type: '+ str(type(obj)))
    seen_ids = set()
    size = 0
    objects = [obj]
    while objects:
        need_referents = []
        for obj in objects:
            if not isinstance(obj, BLACKLIST) and id(obj) not in seen_ids:
                seen_ids.add(id(obj))
                size += sys.getsizeof(obj)
                need_referents.append(obj)
        objects = get_referents(*need_referents)
    return size

# %%
getsize(d['cat']['model'])/(1024*1024)
# Out:
# 4.395211219787598

# %%
with open('./sample_cat_model.joblib', 'wb') as f:
    joblib.dump(d['cat']['model'], f)

# %%
os.listdir(c_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.listdir(c_dir)
#
# NameError: name 'c_dir' is not defined

# %%
sorted(os.listdir(all_dir), key=lambda x: int(x.split('_')[2]), reverse=True)
# Out:
# ['all_results_250_8.joblib',
#  'all_results_250_10.joblib',
#  'all_results_250_0.joblib',
#  'all_results_250_14.joblib',
#  'all_results_250_4.joblib',
#  'all_results_250_12.joblib',
#  'all_results_250_2.joblib',
#  'all_results_250_6.joblib',
#  'all_results_250_16.joblib',
#  'all_results_249_2.joblib',
#  'all_results_249_18.joblib',
#  'all_results_249_12.joblib',
#  'all_results_249_6.joblib',
#  'all_results_249_16.joblib',
#  'all_results_249_0.joblib',
#  'all_results_249_4.joblib',
#  'all_results_249_8.joblib',
#  'all_results_249_10.joblib',
#  'all_results_249_14.joblib',
#  'all_results_249_20.joblib',
#  'all_results_248_22.joblib',
#  'all_results_248_2.joblib',
#  'all_results_248_28.joblib',
#  'all_results_248_18.joblib',
#  'all_results_248_4.joblib',
#  'all_results_248_24.joblib',
#  'all_results_248_20.joblib',
#  'all_results_248_0.joblib',
#  'all_results_248_10.joblib',
#  'all_results_248_26.joblib',
#  'all_results_248_6.joblib',
#  'all_results_248_16.joblib',
#  'all_results_248_8.joblib',
#  'all_results_248_14.joblib',
#  'all_results_248_12.joblib',
#  'all_results_247_4.joblib',
#  'all_results_247_0.joblib',
#  'all_results_247_16.joblib',
#  'all_results_247_8.joblib',
#  'all_results_247_24.joblib',
#  'all_results_247_2.joblib',
#  'all_results_247_10.joblib',
#  'all_results_247_12.joblib',
#  'all_results_247_20.joblib',
#  'all_results_247_22.joblib',
#  'all_results_247_18.joblib',
#  'all_results_247_28.joblib',
#  'all_results_247_26.joblib',
#  'all_results_247_14.joblib',
#  'all_results_247_6.joblib',
#  'all_results_246_28.joblib',
#  'all_results_246_16.joblib',
#  'all_results_246_22.joblib',
#  'all_results_246_8.joblib',
#  'all_results_246_20.joblib',
#  'all_results_246_12.joblib',
#  'all_results_246_2.joblib',
#  'all_results_246_24.joblib',
#  'all_results_246_18.joblib',
#  'all_results_246_6.joblib',
#  'all_results_246_14.joblib',
#  'all_results_246_26.joblib',
#  'all_results_246_10.joblib',
#  'all_results_246_4.joblib',
#  'all_results_246_0.joblib',
#  'all_results_245_4.joblib',
#  'all_results_245_6.joblib',
#  'all_results_245_16.joblib',
#  'all_results_245_10.joblib',
#  'all_results_245_22.joblib',
#  'all_results_245_8.joblib',
#  'all_results_245_28.joblib',
#  'all_results_245_26.joblib',
#  'all_results_245_14.joblib',
#  'all_results_245_2.joblib',
#  'all_results_245_0.joblib',
#  'all_results_245_20.joblib',
#  'all_results_245_12.joblib',
#  'all_results_245_18.joblib',
#  'all_results_245_24.joblib',
#  'all_results_244_4.joblib',
#  'all_results_244_0.joblib',
#  'all_results_244_26.joblib',
#  'all_results_244_24.joblib',
#  'all_results_244_16.joblib',
#  'all_results_244_28.joblib',
#  'all_results_244_22.joblib',
#  'all_results_244_6.joblib',
#  'all_results_244_8.joblib',
#  'all_results_244_20.joblib',
#  'all_results_244_14.joblib',
#  'all_results_244_18.joblib',
#  'all_results_244_10.joblib',
#  'all_results_244_2.joblib',
#  'all_results_244_12.joblib',
#  'all_results_243_24.joblib',
#  'all_results_243_4.joblib',
#  'all_results_243_26.joblib',
#  'all_results_243_8.joblib',
#  'all_results_243_14.joblib',
#  'all_results_243_12.joblib',
#  'all_results_243_20.joblib',
#  'all_results_243_16.joblib',
#  'all_results_243_22.joblib',
#  'all_results_243_28.joblib',
#  'all_results_243_18.joblib',
#  'all_results_243_2.joblib',
#  'all_results_243_6.joblib',
#  'all_results_243_0.joblib',
#  'all_results_243_10.joblib',
#  'all_results_242_26.joblib',
#  'all_results_242_4.joblib',
#  'all_results_242_12.joblib',
#  'all_results_242_10.joblib',
#  'all_results_242_0.joblib',
#  'all_results_242_2.joblib',
#  'all_results_242_16.joblib',
#  'all_results_242_28.joblib',
#  'all_results_242_8.joblib',
#  'all_results_242_20.joblib',
#  'all_results_242_6.joblib',
#  'all_results_242_24.joblib',
#  'all_results_242_22.joblib',
#  'all_results_242_14.joblib',
#  'all_results_242_18.joblib',
#  'all_results_241_22.joblib',
#  'all_results_241_26.joblib',
#  'all_results_241_20.joblib',
#  'all_results_241_14.joblib',
#  'all_results_241_24.joblib',
#  'all_results_241_12.joblib',
#  'all_results_241_2.joblib',
#  'all_results_241_0.joblib',
#  'all_results_241_18.joblib',
#  'all_results_241_4.joblib',
#  'all_results_241_8.joblib',
#  'all_results_241_16.joblib',
#  'all_results_241_28.joblib',
#  'all_results_241_6.joblib',
#  'all_results_241_10.joblib',
#  'all_results_240_4.joblib',
#  'all_results_240_0.joblib',
#  'all_results_240_28.joblib',
#  'all_results_240_12.joblib',
#  'all_results_240_24.joblib',
#  'all_results_240_6.joblib',
#  'all_results_240_16.joblib',
#  'all_results_240_8.joblib',
#  'all_results_240_26.joblib',
#  'all_results_240_20.joblib',
#  'all_results_240_2.joblib',
#  'all_results_240_22.joblib',
#  'all_results_240_10.joblib',
#  'all_results_240_14.joblib',
#  'all_results_240_18.joblib',
#  'all_results_239_28.joblib',
#  'all_results_239_14.joblib',
#  'all_results_239_18.joblib',
#  'all_results_239_16.joblib',
#  'all_results_239_4.joblib',
#  'all_results_239_20.joblib',
#  'all_results_239_22.joblib',
#  'all_results_239_24.joblib',
#  'all_results_239_6.joblib',
#  'all_results_239_12.joblib',
#  'all_results_239_26.joblib',
#  'all_results_239_2.joblib',
#  'all_results_239_8.joblib',
#  'all_results_239_10.joblib',
#  'all_results_239_0.joblib',
#  'all_results_238_14.joblib',
#  'all_results_238_12.joblib',
#  'all_results_238_10.joblib',
#  'all_results_238_22.joblib',
#  'all_results_238_0.joblib',
#  'all_results_238_6.joblib',
#  'all_results_238_16.joblib',
#  'all_results_238_26.joblib',
#  'all_results_238_24.joblib',
#  'all_results_238_20.joblib',
#  'all_results_238_8.joblib',
#  'all_results_238_4.joblib',
#  'all_results_238_18.joblib',
#  'all_results_238_2.joblib',
#  'all_results_238_28.joblib',
#  'all_results_237_6.joblib',
#  'all_results_237_28.joblib',
#  'all_results_237_20.joblib',
#  'all_results_237_26.joblib',
#  'all_results_237_22.joblib',
#  'all_results_237_16.joblib',
#  'all_results_237_12.joblib',
#  'all_results_237_8.joblib',
#  'all_results_237_4.joblib',
#  'all_results_237_10.joblib',
#  'all_results_237_24.joblib',
#  'all_results_237_2.joblib',
#  'all_results_237_0.joblib',
#  'all_results_237_14.joblib',
#  'all_results_237_18.joblib',
#  'all_results_236_6.joblib',
#  'all_results_236_0.joblib',
#  'all_results_236_22.joblib',
#  'all_results_236_2.joblib',
#  'all_results_236_14.joblib',
#  'all_results_236_18.joblib',
#  'all_results_236_24.joblib',
#  'all_results_236_4.joblib',
#  'all_results_236_26.joblib',
#  'all_results_236_8.joblib',
#  'all_results_236_10.joblib',
#  'all_results_236_28.joblib',
#  'all_results_236_20.joblib',
#  'all_results_236_16.joblib',
#  'all_results_236_12.joblib',
#  'all_results_235_6.joblib',
#  'all_results_235_28.joblib',
#  'all_results_235_24.joblib',
#  'all_results_235_4.joblib',
#  'all_results_235_20.joblib',
#  'all_results_235_14.joblib',
#  'all_results_235_10.joblib',
#  'all_results_235_18.joblib',
#  'all_results_235_16.joblib',
#  'all_results_235_2.joblib',
#  'all_results_235_26.joblib',
#  'all_results_235_12.joblib',
#  'all_results_235_8.joblib',
#  'all_results_235_0.joblib',
#  'all_results_235_22.joblib',
#  'all_results_234_8.joblib',
#  'all_results_234_6.joblib',
#  'all_results_234_14.joblib',
#  'all_results_234_2.joblib',
#  'all_results_234_16.joblib',
#  'all_results_234_12.joblib',
#  'all_results_234_28.joblib',
#  'all_results_234_24.joblib',
#  'all_results_234_4.joblib',
#  'all_results_234_22.joblib',
#  'all_results_234_20.joblib',
#  'all_results_234_10.joblib',
#  'all_results_234_26.joblib',
#  'all_results_234_18.joblib',
#  'all_results_234_0.joblib',
#  'all_results_233_26.joblib',
#  'all_results_233_24.joblib',
#  'all_results_233_2.joblib',
#  'all_results_233_10.joblib',
#  'all_results_233_8.joblib',
#  'all_results_233_12.joblib',
#  'all_results_233_4.joblib',
#  'all_results_233_18.joblib',
#  'all_results_233_16.joblib',
#  'all_results_233_0.joblib',
#  'all_results_233_22.joblib',
#  'all_results_233_6.joblib',
#  'all_results_233_28.joblib',
#  'all_results_233_14.joblib',
#  'all_results_233_20.joblib',
#  'all_results_232_26.joblib',
#  'all_results_232_22.joblib',
#  'all_results_232_8.joblib',
#  'all_results_232_0.joblib',
#  'all_results_232_20.joblib',
#  'all_results_232_4.joblib',
#  'all_results_232_2.joblib',
#  'all_results_232_14.joblib',
#  'all_results_232_28.joblib',
#  'all_results_232_16.joblib',
#  'all_results_232_6.joblib',
#  'all_results_232_10.joblib',
#  'all_results_232_18.joblib',
#  'all_results_232_24.joblib',
#  'all_results_232_12.joblib',
#  'all_results_231_6.joblib',
#  'all_results_231_2.joblib',
#  'all_results_231_22.joblib',
#  'all_results_231_20.joblib',
#  'all_results_231_10.joblib',
#  'all_results_231_14.joblib',
#  'all_results_231_4.joblib',
#  'all_results_231_24.joblib',
#  'all_results_231_18.joblib',
#  'all_results_231_16.joblib',
#  'all_results_231_12.joblib',
#  'all_results_231_0.joblib',
#  'all_results_231_8.joblib',
#  'all_results_231_28.joblib',
#  'all_results_231_26.joblib',
#  'all_results_230_26.joblib',
#  'all_results_230_12.joblib',
#  'all_results_230_0.joblib',
#  'all_results_230_20.joblib',
#  'all_results_230_28.joblib',
#  'all_results_230_16.joblib',
#  'all_results_230_8.joblib',
#  'all_results_230_2.joblib',
#  'all_results_230_14.joblib',
#  'all_results_230_22.joblib',
#  'all_results_230_10.joblib',
#  'all_results_230_18.joblib',
#  'all_results_230_24.joblib',
#  'all_results_230_6.joblib',
#  'all_results_230_4.joblib',
#  'all_results_229_10.joblib',
#  'all_results_229_0.joblib',
#  'all_results_229_16.joblib',
#  'all_results_229_28.joblib',
#  'all_results_229_4.joblib',
#  'all_results_229_12.joblib',
#  'all_results_229_22.joblib',
#  'all_results_229_24.joblib',
#  'all_results_229_8.joblib',
#  'all_results_229_6.joblib',
#  'all_results_229_20.joblib',
#  'all_results_229_18.joblib',
#  'all_results_229_26.joblib',
#  'all_results_229_14.joblib',
#  'all_results_229_2.joblib',
#  'all_results_228_12.joblib',
#  'all_results_228_18.joblib',
#  'all_results_228_26.joblib',
#  'all_results_228_4.joblib',
#  'all_results_228_16.joblib',
#  'all_results_228_2.joblib',
#  'all_results_228_14.joblib',
#  'all_results_228_28.joblib',
#  'all_results_228_20.joblib',
#  'all_results_228_22.joblib',
#  'all_results_228_10.joblib',
#  'all_results_228_24.joblib',
#  'all_results_228_8.joblib',
#  'all_results_228_0.joblib',
#  'all_results_228_6.joblib',
#  'all_results_227_6.joblib',
#  'all_results_227_26.joblib',
#  'all_results_227_8.joblib',
#  'all_results_227_12.joblib',
#  'all_results_227_18.joblib',
#  'all_results_227_4.joblib',
#  'all_results_227_22.joblib',
#  'all_results_227_24.joblib',
#  'all_results_227_0.joblib',
#  'all_results_227_2.joblib',
#  'all_results_227_16.joblib',
#  'all_results_227_28.joblib',
#  'all_results_227_10.joblib',
#  'all_results_227_20.joblib',
#  'all_results_227_14.joblib',
#  'all_results_226_8.joblib',
#  'all_results_226_0.joblib',
#  'all_results_226_20.joblib',
#  'all_results_226_24.joblib',
#  'all_results_226_2.joblib',
#  'all_results_226_16.joblib',
#  'all_results_226_18.joblib',
#  'all_results_226_10.joblib',
#  'all_results_226_26.joblib',
#  'all_results_226_28.joblib',
#  'all_results_226_14.joblib',
#  'all_results_226_22.joblib',
#  'all_results_226_4.joblib',
#  'all_results_226_12.joblib',
#  'all_results_226_6.joblib',
#  'all_results_225_26.joblib',
#  'all_results_225_28.joblib',
#  'all_results_225_16.joblib',
#  'all_results_225_20.joblib',
#  'all_results_225_8.joblib',
#  'all_results_225_0.joblib',
#  'all_results_225_22.joblib',
#  'all_results_225_4.joblib',
#  'all_results_225_14.joblib',
#  'all_results_225_18.joblib',
#  'all_results_225_24.joblib',
#  'all_results_225_2.joblib',
#  'all_results_225_10.joblib',
#  'all_results_225_12.joblib',
#  'all_results_225_6.joblib',
#  'all_results_224_26.joblib',
#  'all_results_224_28.joblib',
#  'all_results_224_4.joblib',
#  'all_results_224_16.joblib',
#  'all_results_224_18.joblib',
#  'all_results_224_20.joblib',
#  'all_results_224_22.joblib',
#  'all_results_224_10.joblib',
#  'all_results_224_24.joblib',
#  'all_results_224_2.joblib',
#  'all_results_224_14.joblib',
#  'all_results_224_12.joblib',
#  'all_results_224_0.joblib',
#  'all_results_224_6.joblib',
#  'all_results_224_8.joblib',
#  'all_results_223_26.joblib',
#  'all_results_223_28.joblib',
#  'all_results_223_20.joblib',
#  'all_results_223_8.joblib',
#  'all_results_223_22.joblib',
#  'all_results_223_12.joblib',
#  'all_results_223_24.joblib',
#  'all_results_223_16.joblib',
#  'all_results_223_4.joblib',
#  'all_results_223_18.joblib',
#  'all_results_223_0.joblib',
#  'all_results_223_2.joblib',
#  'all_results_223_10.joblib',
#  'all_results_223_14.joblib',
#  'all_results_223_6.joblib',
#  'all_results_222_22.joblib',
#  'all_results_222_2.joblib',
#  'all_results_222_10.joblib',
#  'all_results_222_4.joblib',
#  'all_results_222_16.joblib',
#  'all_results_222_0.joblib',
#  'all_results_222_8.joblib',
#  'all_results_222_14.joblib',
#  'all_results_222_20.joblib',
#  'all_results_222_18.joblib',
#  'all_results_222_28.joblib',
#  'all_results_222_24.joblib',
#  'all_results_222_6.joblib',
#  'all_results_222_12.joblib',
#  'all_results_222_26.joblib',
#  'all_results_221_8.joblib',
#  'all_results_221_6.joblib',
#  'all_results_221_4.joblib',
#  'all_results_221_18.joblib',
#  'all_results_221_24.joblib',
#  'all_results_221_22.joblib',
#  'all_results_221_20.joblib',
#  'all_results_221_12.joblib',
#  'all_results_221_26.joblib',
#  'all_results_221_28.joblib',
#  'all_results_221_14.joblib',
#  'all_results_221_10.joblib',
#  'all_results_221_0.joblib',
#  'all_results_221_16.joblib',
#  'all_results_221_2.joblib',
#  'all_results_220_4.joblib',
#  'all_results_220_2.joblib',
#  'all_results_220_16.joblib',
#  'all_results_220_18.joblib',
#  'all_results_220_26.joblib',
#  'all_results_220_24.joblib',
#  'all_results_220_20.joblib',
#  'all_results_220_14.joblib',
#  'all_results_220_22.joblib',
#  'all_results_220_0.joblib',
#  'all_results_220_10.joblib',
#  'all_results_220_12.joblib',
#  'all_results_220_6.joblib',
#  'all_results_220_8.joblib',
#  'all_results_220_28.joblib',
#  'all_results_219_2.joblib',
#  'all_results_219_18.joblib',
#  'all_results_219_26.joblib',
#  'all_results_219_24.joblib',
#  'all_results_219_22.joblib',
#  'all_results_219_6.joblib',
#  'all_results_219_8.joblib',
#  'all_results_219_0.joblib',
#  'all_results_219_12.joblib',
#  'all_results_219_28.joblib',
#  'all_results_219_20.joblib',
#  'all_results_219_10.joblib',
#  'all_results_219_14.joblib',
#  'all_results_219_16.joblib',
#  'all_results_219_4.joblib',
#  'all_results_218_28.joblib',
#  'all_results_218_0.joblib',
#  'all_results_218_16.joblib',
#  'all_results_218_20.joblib',
#  'all_results_218_18.joblib',
#  'all_results_218_10.joblib',
#  'all_results_218_14.joblib',
#  'all_results_218_2.joblib',
#  'all_results_218_26.joblib',
#  'all_results_218_4.joblib',
#  'all_results_218_12.joblib',
#  'all_results_218_8.joblib',
#  'all_results_218_24.joblib',
#  'all_results_218_22.joblib',
#  'all_results_218_6.joblib',
#  'all_results_217_24.joblib',
#  'all_results_217_14.joblib',
#  'all_results_217_28.joblib',
#  'all_results_217_0.joblib',
#  'all_results_217_8.joblib',
#  'all_results_217_16.joblib',
#  'all_results_217_18.joblib',
#  'all_results_217_22.joblib',
#  'all_results_217_26.joblib',
#  'all_results_217_10.joblib',
#  'all_results_217_20.joblib',
#  'all_results_217_6.joblib',
#  'all_results_217_4.joblib',
#  'all_results_217_12.joblib',
#  'all_results_217_2.joblib',
#  'all_results_216_8.joblib',
#  'all_results_216_10.joblib',
#  'all_results_216_12.joblib',
#  'all_results_216_24.joblib',
#  'all_results_216_0.joblib',
#  'all_results_216_28.joblib',
#  'all_results_216_4.joblib',
#  'all_results_216_16.joblib',
#  'all_results_216_6.joblib',
#  'all_results_216_20.joblib',
#  'all_results_216_2.joblib',
#  'all_results_216_22.joblib',
#  'all_results_216_18.joblib',
#  'all_results_216_26.joblib',
#  'all_results_216_14.joblib',
#  'all_results_215_2.joblib',
#  'all_results_215_4.joblib',
#  'all_results_215_8.joblib',
#  'all_results_215_14.joblib',
#  'all_results_215_12.joblib',
#  'all_results_215_28.joblib',
#  'all_results_215_26.joblib',
#  'all_results_215_10.joblib',
#  'all_results_215_6.joblib',
#  'all_results_215_24.joblib',
#  'all_results_215_20.joblib',
#  'all_results_215_16.joblib',
#  'all_results_215_22.joblib',
#  'all_results_215_0.joblib',
#  'all_results_215_18.joblib',
#  'all_results_214_16.joblib',
#  'all_results_214_8.joblib',
#  'all_results_214_4.joblib',
#  'all_results_214_14.joblib',
#  'all_results_214_18.joblib',
#  'all_results_214_2.joblib',
#  'all_results_214_0.joblib',
#  'all_results_214_12.joblib',
#  'all_results_214_20.joblib',
#  'all_results_214_6.joblib',
#  'all_results_214_10.joblib',
#  'all_results_213_8.joblib',
#  'all_results_213_16.joblib',
#  'all_results_213_14.joblib',
#  'all_results_213_22.joblib',
#  'all_results_213_6.joblib',
#  'all_results_213_0.joblib',
#  'all_results_213_2.joblib',
#  'all_results_213_28.joblib',
#  'all_results_213_24.joblib',
#  'all_results_213_26.joblib',
#  'all_results_213_4.joblib',
#  'all_results_213_10.joblib',
#  'all_results_213_20.joblib',
#  'all_results_213_12.joblib',
#  'all_results_213_18.joblib',
#  'all_results_212_24.joblib',
#  'all_results_212_26.joblib',
#  'all_results_212_22.joblib',
#  'all_results_212_18.joblib',
#  'all_results_212_20.joblib',
#  'all_results_212_4.joblib',
#  'all_results_212_10.joblib',
#  'all_results_212_0.joblib',
#  'all_results_212_14.joblib',
#  'all_results_212_6.joblib',
#  'all_results_212_28.joblib',
#  'all_results_212_16.joblib',
#  'all_results_212_2.joblib',
#  'all_results_212_8.joblib',
#  'all_results_212_12.joblib',
#  'all_results_211_6.joblib',
#  'all_results_211_28.joblib',
#  'all_results_211_14.joblib',
#  'all_results_211_8.joblib',
#  'all_results_211_10.joblib',
#  'all_results_211_0.joblib',
#  'all_results_211_12.joblib',
#  'all_results_211_22.joblib',
#  'all_results_211_2.joblib',
#  'all_results_211_26.joblib',
#  'all_results_211_16.joblib',
#  'all_results_211_4.joblib',
#  'all_results_211_24.joblib',
#  'all_results_211_18.joblib',
#  'all_results_211_20.joblib',
#  'all_results_210_16.joblib',
#  'all_results_210_26.joblib',
#  'all_results_210_22.joblib',
#  'all_results_210_24.joblib',
#  'all_results_210_20.joblib',
#  'all_results_210_0.joblib',
#  'all_results_210_10.joblib',
#  'all_results_210_2.joblib',
#  'all_results_210_14.joblib',
#  'all_results_210_8.joblib',
#  'all_results_210_4.joblib',
#  'all_results_210_18.joblib',
#  'all_results_210_28.joblib',
#  'all_results_210_6.joblib',
#  'all_results_210_12.joblib',
#  'all_results_209_18.joblib',
#  'all_results_209_14.joblib',
#  'all_results_209_22.joblib',
#  'all_results_209_16.joblib',
#  'all_results_209_10.joblib',
#  'all_results_209_20.joblib',
#  'all_results_209_8.joblib',
#  'all_results_209_6.joblib',
#  'all_results_209_0.joblib',
#  'all_results_209_26.joblib',
#  'all_results_209_2.joblib',
#  'all_results_209_12.joblib',
#  'all_results_209_4.joblib',
#  'all_results_209_24.joblib',
#  'all_results_209_28.joblib',
#  'all_results_208_28.joblib',
#  'all_results_208_4.joblib',
#  'all_results_208_26.joblib',
#  'all_results_208_20.joblib',
#  'all_results_208_16.joblib',
#  'all_results_208_6.joblib',
#  'all_results_208_0.joblib',
#  'all_results_208_10.joblib',
#  'all_results_208_2.joblib',
#  'all_results_208_8.joblib',
#  'all_results_208_12.joblib',
#  'all_results_208_22.joblib',
#  'all_results_208_18.joblib',
#  'all_results_208_24.joblib',
#  'all_results_208_14.joblib',
#  'all_results_207_26.joblib',
#  'all_results_207_2.joblib',
#  'all_results_207_12.joblib',
#  'all_results_207_0.joblib',
#  'all_results_207_28.joblib',
#  'all_results_207_10.joblib',
#  'all_results_207_8.joblib',
#  'all_results_207_24.joblib',
#  'all_results_207_6.joblib',
#  'all_results_207_14.joblib',
#  'all_results_207_16.joblib',
#  'all_results_207_22.joblib',
#  'all_results_207_20.joblib',
#  'all_results_207_4.joblib',
#  'all_results_207_18.joblib',
#  'all_results_206_2.joblib',
#  'all_results_206_16.joblib',
#  'all_results_206_20.joblib',
#  'all_results_206_4.joblib',
#  'all_results_206_24.joblib',
#  'all_results_206_28.joblib',
#  'all_results_206_12.joblib',
#  'all_results_206_10.joblib',
#  'all_results_206_14.joblib',
#  'all_results_206_8.joblib',
#  'all_results_206_18.joblib',
#  'all_results_206_22.joblib',
#  'all_results_206_0.joblib',
#  'all_results_206_6.joblib',
#  'all_results_206_26.joblib',
#  'all_results_205_10.joblib',
#  'all_results_205_14.joblib',
#  'all_results_205_16.joblib',
#  'all_results_205_2.joblib',
#  'all_results_205_4.joblib',
#  'all_results_205_0.joblib',
#  'all_results_205_24.joblib',
#  'all_results_205_22.joblib',
#  'all_results_205_12.joblib',
#  'all_results_205_8.joblib',
#  'all_results_205_20.joblib',
#  'all_results_205_26.joblib',
#  'all_results_205_6.joblib',
#  'all_results_205_28.joblib',
#  'all_results_205_18.joblib',
#  'all_results_204_18.joblib',
#  'all_results_204_22.joblib',
#  'all_results_204_14.joblib',
#  'all_results_204_0.joblib',
#  'all_results_204_26.joblib',
#  'all_results_204_2.joblib',
#  'all_results_204_4.joblib',
#  'all_results_204_10.joblib',
#  'all_results_204_12.joblib',
#  'all_results_204_6.joblib',
#  'all_results_204_8.joblib',
#  'all_results_204_20.joblib',
#  'all_results_204_16.joblib',
#  'all_results_204_24.joblib',
#  'all_results_204_28.joblib',
#  'all_results_203_24.joblib',
#  'all_results_203_18.joblib',
#  'all_results_203_14.joblib',
#  'all_results_203_10.joblib',
#  'all_results_203_12.joblib',
#  'all_results_203_20.joblib',
#  'all_results_203_4.joblib',
#  'all_results_203_26.joblib',
#  'all_results_203_8.joblib',
#  'all_results_203_0.joblib',
#  'all_results_203_22.joblib',
#  'all_results_203_2.joblib',
#  'all_results_203_6.joblib',
#  'all_results_203_28.joblib',
#  'all_results_203_16.joblib',
#  'all_results_202_10.joblib',
#  'all_results_202_4.joblib',
#  'all_results_202_18.joblib',
#  'all_results_202_22.joblib',
#  'all_results_202_26.joblib',
#  'all_results_202_24.joblib',
#  'all_results_202_16.joblib',
#  'all_results_202_28.joblib',
#  'all_results_202_8.joblib',
#  'all_results_202_6.joblib',
#  'all_results_202_12.joblib',
#  'all_results_202_14.joblib',
#  'all_results_202_20.joblib',
#  'all_results_202_2.joblib',
#  'all_results_202_0.joblib',
#  'all_results_201_4.joblib',
#  'all_results_201_12.joblib',
#  'all_results_201_8.joblib',
#  'all_results_201_2.joblib',
#  'all_results_201_16.joblib',
#  'all_results_201_20.joblib',
#  'all_results_201_18.joblib',
#  'all_results_201_0.joblib',
#  'all_results_201_26.joblib',
#  'all_results_201_28.joblib',
#  'all_results_201_6.joblib',
#  'all_results_201_14.joblib',
#  'all_results_201_22.joblib',
#  'all_results_201_24.joblib',
#  'all_results_201_10.joblib',
#  'all_results_200_0.joblib',
#  'all_results_200_10.joblib',
#  'all_results_200_16.joblib',
#  'all_results_200_24.joblib',
#  'all_results_200_18.joblib',
#  'all_results_200_26.joblib',
#  'all_results_200_20.joblib',
#  'all_results_200_4.joblib',
#  'all_results_200_28.joblib',
#  'all_results_200_8.joblib',
#  'all_results_200_2.joblib',
#  'all_results_200_6.joblib',
#  'all_results_200_22.joblib',
#  'all_results_200_12.joblib',
#  'all_results_200_14.joblib',
#  'all_results_199_18.joblib',
#  'all_results_199_4.joblib',
#  'all_results_199_6.joblib',
#  'all_results_199_0.joblib',
#  'all_results_199_24.joblib',
#  'all_results_199_2.joblib',
#  'all_results_199_10.joblib',
#  'all_results_199_22.joblib',
#  'all_results_199_26.joblib',
#  'all_results_199_12.joblib',
#  'all_results_199_14.joblib',
#  'all_results_199_28.joblib',
#  'all_results_199_16.joblib',
#  'all_results_199_20.joblib',
#  'all_results_199_8.joblib',
#  'all_results_198_26.joblib',
#  'all_results_198_16.joblib',
#  'all_results_198_24.joblib',
#  'all_results_198_12.joblib',
#  'all_results_198_4.joblib',
#  'all_results_198_10.joblib',
#  'all_results_198_0.joblib',
#  'all_results_198_8.joblib',
#  'all_results_198_22.joblib',
#  'all_results_198_20.joblib',
#  'all_results_198_6.joblib',
#  'all_results_198_14.joblib',
#  'all_results_198_2.joblib',
#  'all_results_198_28.joblib',
#  'all_results_198_18.joblib',
#  'all_results_197_16.joblib',
#  'all_results_197_8.joblib',
#  'all_results_197_22.joblib',
#  'all_results_197_0.joblib',
#  'all_results_197_24.joblib',
#  'all_results_197_2.joblib',
#  'all_results_197_26.joblib',
#  'all_results_197_14.joblib',
#  'all_results_197_12.joblib',
#  'all_results_197_20.joblib',
#  'all_results_197_4.joblib',
#  'all_results_197_18.joblib',
#  'all_results_197_6.joblib',
#  'all_results_197_28.joblib',
#  'all_results_197_10.joblib',
#  'all_results_196_16.joblib',
#  'all_results_196_4.joblib',
#  'all_results_196_22.joblib',
#  'all_results_196_10.joblib',
#  'all_results_196_0.joblib',
#  'all_results_196_20.joblib',
#  'all_results_196_14.joblib',
#  'all_results_196_18.joblib',
#  'all_results_196_24.joblib',
#  'all_results_196_2.joblib',
#  'all_results_196_12.joblib',
#  'all_results_196_26.joblib',
#  'all_results_196_28.joblib',
#  'all_results_196_8.joblib',
#  'all_results_196_6.joblib',
#  'all_results_195_12.joblib',
#  'all_results_195_24.joblib',
#  'all_results_195_2.joblib',
#  'all_results_195_28.joblib',
#  'all_results_195_14.joblib',
#  'all_results_195_0.joblib',
#  'all_results_195_18.joblib',
#  'all_results_195_22.joblib',
#  'all_results_195_6.joblib',
#  'all_results_195_20.joblib',
#  'all_results_195_8.joblib',
#  'all_results_195_16.joblib',
#  'all_results_195_10.joblib',
#  'all_results_195_26.joblib',
#  'all_results_195_4.joblib',
#  'all_results_194_4.joblib',
#  'all_results_194_18.joblib',
#  'all_results_194_10.joblib',
#  'all_results_194_28.joblib',
#  'all_results_194_16.joblib',
#  'all_results_194_26.joblib',
#  'all_results_194_8.joblib',
#  'all_results_194_0.joblib',
#  'all_results_194_2.joblib',
#  'all_results_194_6.joblib',
#  'all_results_194_22.joblib',
#  'all_results_194_24.joblib',
#  'all_results_194_12.joblib',
#  'all_results_194_20.joblib',
#  'all_results_194_14.joblib',
#  'all_results_193_4.joblib',
#  'all_results_193_8.joblib',
#  'all_results_193_2.joblib',
#  'all_results_193_10.joblib',
#  'all_results_193_18.joblib',
#  'all_results_193_0.joblib',
#  'all_results_193_12.joblib',
#  'all_results_193_6.joblib',
#  'all_results_193_14.joblib',
#  'all_results_193_24.joblib',
#  'all_results_193_26.joblib',
#  'all_results_193_22.joblib',
#  'all_results_193_20.joblib',
#  'all_results_193_28.joblib',
#  'all_results_193_16.joblib',
#  'all_results_192_10.joblib',
#  'all_results_192_14.joblib',
#  'all_results_192_20.joblib',
#  'all_results_192_12.joblib',
#  'all_results_192_22.joblib',
#  'all_results_192_26.joblib',
#  'all_results_192_16.joblib',
#  'all_results_192_24.joblib',
#  'all_results_192_2.joblib',
#  'all_results_192_0.joblib',
#  'all_results_192_8.joblib',
#  'all_results_192_6.joblib',
#  'all_results_192_28.joblib',
#  'all_results_192_4.joblib',
#  'all_results_192_18.joblib',
#  'all_results_191_4.joblib',
#  'all_results_191_8.joblib',
#  'all_results_191_20.joblib',
#  'all_results_191_12.joblib',
#  'all_results_191_6.joblib',
#  'all_results_191_22.joblib',
#  'all_results_191_18.joblib',
#  'all_results_191_14.joblib',
#  'all_results_191_16.joblib',
#  'all_results_191_28.joblib',
#  'all_results_191_26.joblib',
#  'all_results_191_2.joblib',
#  'all_results_191_10.joblib',
#  'all_results_191_0.joblib',
#  'all_results_191_24.joblib',
#  'all_results_190_16.joblib',
#  'all_results_190_22.joblib',
#  'all_results_190_26.joblib',
#  'all_results_190_8.joblib',
#  'all_results_190_20.joblib',
#  'all_results_190_10.joblib',
#  'all_results_190_0.joblib',
#  'all_results_190_12.joblib',
#  'all_results_190_2.joblib',
#  'all_results_190_24.joblib',
#  'all_results_190_18.joblib',
#  'all_results_190_14.joblib',
#  'all_results_190_4.joblib',
#  'all_results_190_6.joblib',
#  'all_results_190_28.joblib',
#  'all_results_189_12.joblib',
#  'all_results_189_28.joblib',
#  'all_results_189_18.joblib',
#  'all_results_189_4.joblib',
#  'all_results_189_8.joblib',
#  'all_results_189_2.joblib',
#  'all_results_189_10.joblib',
#  'all_results_189_24.joblib',
#  'all_results_189_14.joblib',
#  'all_results_189_6.joblib',
#  'all_results_189_16.joblib',
#  'all_results_189_26.joblib',
#  'all_results_189_20.joblib',
#  'all_results_189_0.joblib',
#  'all_results_189_22.joblib',
#  'all_results_188_28.joblib',
#  'all_results_188_4.joblib',
#  'all_results_188_24.joblib',
#  'all_results_188_20.joblib',
#  'all_results_188_2.joblib',
#  'all_results_188_26.joblib',
#  'all_results_188_22.joblib',
#  'all_results_188_6.joblib',
#  'all_results_188_16.joblib',
#  'all_results_188_10.joblib',
#  'all_results_188_14.joblib',
#  'all_results_188_18.joblib',
#  'all_results_188_12.joblib',
#  'all_results_188_0.joblib',
#  'all_results_188_8.joblib',
#  'all_results_187_8.joblib',
#  'all_results_187_10.joblib',
#  'all_results_187_22.joblib',
#  'all_results_187_14.joblib',
#  'all_results_187_24.joblib',
#  'all_results_187_4.joblib',
#  'all_results_187_6.joblib',
#  'all_results_187_28.joblib',
#  'all_results_187_2.joblib',
#  'all_results_187_18.joblib',
#  'all_results_187_26.joblib',
#  'all_results_187_0.joblib',
#  'all_results_187_20.joblib',
#  'all_results_187_12.joblib',
#  'all_results_187_16.joblib',
#  'all_results_186_16.joblib',
#  'all_results_186_22.joblib',
#  'all_results_186_20.joblib',
#  'all_results_186_12.joblib',
#  'all_results_186_26.joblib',
#  'all_results_186_10.joblib',
#  'all_results_186_2.joblib',
#  'all_results_186_24.joblib',
#  'all_results_186_0.joblib',
#  'all_results_186_4.joblib',
#  'all_results_186_14.joblib',
#  'all_results_186_28.joblib',
#  'all_results_186_6.joblib',
#  'all_results_186_8.joblib',
#  'all_results_186_18.joblib',
#  'all_results_185_20.joblib',
#  'all_results_185_14.joblib',
#  'all_results_185_24.joblib',
#  'all_results_185_28.joblib',
#  'all_results_185_12.joblib',
#  'all_results_185_16.joblib',
#  'all_results_185_2.joblib',
#  'all_results_185_22.joblib',
#  'all_results_185_10.joblib',
#  'all_results_185_18.joblib',
#  'all_results_185_26.joblib',
#  'all_results_185_0.joblib',
#  'all_results_185_4.joblib',
#  'all_results_185_6.joblib',
#  'all_results_185_8.joblib',
#  'all_results_184_22.joblib',
#  'all_results_184_24.joblib',
#  'all_results_184_10.joblib',
#  'all_results_184_4.joblib',
#  'all_results_184_8.joblib',
#  'all_results_184_2.joblib',
#  'all_results_184_18.joblib',
#  'all_results_184_0.joblib',
#  'all_results_184_6.joblib',
#  'all_results_184_20.joblib',
#  'all_results_184_26.joblib',
#  'all_results_184_28.joblib',
#  'all_results_184_12.joblib',
#  'all_results_184_16.joblib',
#  'all_results_184_14.joblib',
#  'all_results_183_26.joblib',
#  'all_results_183_18.joblib',
#  'all_results_183_20.joblib',
#  'all_results_183_16.joblib',
#  'all_results_183_14.joblib',
#  'all_results_183_8.joblib',
#  'all_results_183_4.joblib',
#  'all_results_183_28.joblib',
#  'all_results_183_12.joblib',
#  ...]

# %%
def agg_eidx_dict(files_list):
    dd = defaultdict(list)
    for file in files_list:
        dd[int(file.split('_')[2])].append(file)
    return dd

# %%
# Analyze ALL model
all_files = [file for file in os.listdir(all_dir) if file.startswith('all') and file.endswith('.joblib')] 
all_files = sorted(all_files, key = lambda x: (int(x.split('_')[2]), int(x.split('_')[-1].split('.')[0])), reverse=False)
all_dict = agg_eidx_dict(all_files)

all_index = []
all_train_bacc = []
all_train_ppv = []
all_train_roc = []

all_val_bacc = []
all_val_ppv = []
all_val_roc = []

all_test_bacc = []
all_test_ppv = []
all_test_roc = []

for key in all_dict:
    all_files_in_order = sorted(all_dict[key], key=lambda x: (int(x.split('_')[3].split('.')[0]), x.split('_')[2]), reverse=True)
    all_index.append(key)
    train_bacc = []
    train_ppv = []
    train_roc = []
    
    val_bacc = []
    val_ppv = []
    val_roc = []
    
    test_bacc = []
    test_ppv = []
    test_roc = []
    for file in all_files_in_order:
        with open(os.path.join(all_dir, file), 'rb') as f:
            all_result_data = joblib.load(f)
        clc = 'cat'
        train_bacc.append(all_result_data[clc]['train_score_avg']['bacc'])
        train_ppv.append(all_result_data[clc]['train_score_avg']['ppv'])
        train_roc.append(all_result_data[clc]['train_score_avg']['roc'])
        
        val_bacc.append(all_result_data[clc]['val_score_avg']['bacc'])
        val_ppv.append(all_result_data[clc]['val_score_avg']['ppv'])
        val_roc.append(all_result_data[clc]['val_score_avg']['roc'])
        
        test_bacc.append(all_result_data[clc]['test_results']['bacc'])
        test_ppv.append(all_result_data[clc]['test_results']['ppv'])
        test_roc.append(all_result_data[clc]['test_results']['roc'])
    
            
    # all_train_bacc.append(train_bacc)
    # all_train_ppv.append(train_ppv)
    # all_train_roc.append(train_roc)
    
    
    # all_val_bacc.append(val_bacc)
    # all_val_ppv.append(val_ppv)
    # all_val_roc.append(val_roc)

    # all_test_bacc.append(test_bacc)
    # all_test_ppv.append(test_ppv)
    # all_test_roc.append(test_roc)
    all_train_bacc.append((np.mean(train_bacc), np.std(train_bacc, ddof=1)))
    all_train_ppv.append((np.mean(train_ppv), np.std(train_ppv, ddof=1)))
    all_train_roc.append((np.mean(train_roc), np.std(train_roc, ddof=1)))
    
    
    all_val_bacc.append((np.mean(val_bacc), np.std(val_bacc, ddof=1)))
    all_val_ppv.append((np.mean(val_ppv), np.std(val_ppv, ddof=1)))
    all_val_roc.append((np.mean(val_roc), np.std(val_roc, ddof=1)))

    all_test_bacc.append((np.mean(test_bacc), np.std(test_bacc, ddof=1)))
    all_test_ppv.append((np.mean(test_ppv), np.std(test_ppv, ddof=1)))
    all_test_roc.append((np.mean(test_roc), np.std(test_roc, ddof=1)))

# %%
fig, ax = plt.subplots(figsize=(22,8), dpi=160)
plt.errorbar(all_index, list(map(lambda x:x[0], all_test_bacc)), yerr=list(map(lambda x:x[1], all_test_bacc)), fmt='-x', capsize=5)
plt.ylabel('Accuracy')
plt.xlabel('Events')
plt.title("Accuracy across events with mean/std over folds")

fig.savefig("error.png")
plt.show()

# %%
# Analyze Comb model
comb_files = [file for file in os.listdir(comb_dir) if file.startswith('comb') and file.endswith('.joblib')] 
comb_files = sorted(comb_files, key = lambda x: (int(x.split('_')[2]), int(x.split('_')[-1].split('.')[0])), reverse=False)
comb_dict = agg_eidx_dict(comb_files)

comb_index = []
comb_train_bacc = []
comb_train_ppv = []
comb_train_roc = []

comb_val_bacc = []
comb_val_ppv = []
comb_val_roc = []

comb_test_bacc = []
comb_test_ppv = []
comb_test_roc = []

for key in comb_dict:
    comb_files_in_order = sorted(comb_dict[key], key=lambda x: (int(x.split('_')[3].split('.')[0]), x.split('_')[2]), reverse=True)
    comb_index.append(key)
    train_bacc = []
    train_ppv = []
    train_roc = []
    
    val_bacc = []
    val_ppv = []
    val_roc = []
    
    test_bacc = []
    test_ppv = []
    test_roc = []
    for file in comb_files_in_order:
        with open(os.path.join(comb_dir, file), 'rb') as f:
            comb_result_data = joblib.load(f)
        clc = 'cat'
        train_bacc.append(comb_result_data[clc]['train_score_avg']['bacc'])
        train_ppv.append(comb_result_data[clc]['train_score_avg']['ppv'])
        train_roc.append(comb_result_data[clc]['train_score_avg']['roc'])
        
        val_bacc.append(comb_result_data[clc]['val_score_avg']['bacc'])
        val_ppv.append(comb_result_data[clc]['val_score_avg']['ppv'])
        val_roc.append(comb_result_data[clc]['val_score_avg']['roc'])
        
        test_bacc.append(comb_result_data[clc]['test_results']['bacc'])
        test_ppv.append(comb_result_data[clc]['test_results']['ppv'])
        test_roc.append(comb_result_data[clc]['test_results']['roc'])
    
            
    # all_train_bacc.append(train_bacc)
    # all_train_ppv.append(train_ppv)
    # all_train_roc.append(train_roc)
    
    
    # all_val_bacc.append(val_bacc)
    # all_val_ppv.append(val_ppv)
    # all_val_roc.append(val_roc)

    # all_test_bacc.append(test_bacc)
    # all_test_ppv.append(test_ppv)
    # all_test_roc.append(test_roc)
    comb_train_bacc.append((np.mean(train_bacc), np.std(train_bacc, ddof=1)))
    comb_train_ppv.append((np.mean(train_ppv), np.std(train_ppv, ddof=1)))
    comb_train_roc.append((np.mean(train_roc), np.std(train_roc, ddof=1)))
    
    
    comb_val_bacc.append((np.mean(val_bacc), np.std(val_bacc, ddof=1)))
    comb_val_ppv.append((np.mean(val_ppv), np.std(val_ppv, ddof=1)))
    comb_val_roc.append((np.mean(val_roc), np.std(val_roc, ddof=1)))

    comb_test_bacc.append((np.mean(test_bacc), np.std(test_bacc, ddof=1)))
    comb_test_ppv.append((np.mean(test_ppv), np.std(test_ppv, ddof=1)))
    comb_test_roc.append((np.mean(test_roc), np.std(test_roc, ddof=1)))

# %%
# Analyze static model
s_files = [file for file in os.listdir(static_dir) if file.startswith('static') and file.endswith('.joblib')] 
s_files = sorted(s_files, key = lambda x: (int(x.split('_')[2]), int(x.split('_')[-1].split('.')[0])), reverse=False)
s_dict = agg_eidx_dict(s_files)

s_index = []
s_train_bacc = []
s_train_ppv = []
s_train_roc = []

s_val_bacc = []
s_val_ppv = []
s_val_roc = []

s_test_bacc = []
s_test_ppv = []
s_test_roc = []

for key in s_dict:
    s_files_in_order = sorted(s_dict[key], key=lambda x: (int(x.split('_')[3].split('.')[0]), x.split('_')[2]), reverse=True)
    s_index.append(key)
    train_bacc = []
    train_ppv = []
    train_roc = []
    
    val_bacc = []
    val_ppv = []
    val_roc = []
    
    test_bacc = []
    test_ppv = []
    test_roc = []
    for file in s_files_in_order:
        with open(os.path.join(static_dir, file), 'rb') as f:
            s_result_data = joblib.load(f)
        clc = 'cat'
        train_bacc.append(s_result_data[clc]['train_score_avg']['bacc'])
        train_ppv.append(s_result_data[clc]['train_score_avg']['ppv'])
        train_roc.append(s_result_data[clc]['train_score_avg']['roc'])
        
        val_bacc.append(s_result_data[clc]['val_score_avg']['bacc'])
        val_ppv.append(s_result_data[clc]['val_score_avg']['ppv'])
        val_roc.append(s_result_data[clc]['val_score_avg']['roc'])
        
        test_bacc.append(s_result_data[clc]['test_results']['bacc'])
        test_ppv.append(s_result_data[clc]['test_results']['ppv'])
        test_roc.append(s_result_data[clc]['test_results']['roc'])
    
            
    # all_train_bacc.append(train_bacc)
    # all_train_ppv.append(train_ppv)
    # all_train_roc.append(train_roc)
    
    
    # all_val_bacc.append(val_bacc)
    # all_val_ppv.append(val_ppv)
    # all_val_roc.append(val_roc)

    # all_test_bacc.append(test_bacc)
    # all_test_ppv.append(test_ppv)
    # all_test_roc.append(test_roc)
    s_train_bacc.append((np.mean(train_bacc), np.std(train_bacc, ddof=1)))
    s_train_ppv.append((np.mean(train_ppv), np.std(train_ppv, ddof=1)))
    s_train_roc.append((np.mean(train_roc), np.std(train_roc, ddof=1)))
    
    
    s_val_bacc.append((np.mean(val_bacc), np.std(val_bacc, ddof=1)))
    s_val_ppv.append((np.mean(val_ppv), np.std(val_ppv, ddof=1)))
    s_val_roc.append((np.mean(val_roc), np.std(val_roc, ddof=1)))

    s_test_bacc.append((np.mean(test_bacc), np.std(test_bacc, ddof=1)))
    s_test_ppv.append((np.mean(test_ppv), np.std(test_ppv, ddof=1)))
    s_test_roc.append((np.mean(test_roc), np.std(test_roc, ddof=1)))

# %%
# Analyze dynamic model
d_files = [file for file in os.listdir(dynamic_dir) if file.startswith('dynamic') and file.endswith('.joblib')] 
d_files = sorted(d_files, key = lambda x: (int(x.split('_')[2]), int(x.split('_')[-1].split('.')[0])), reverse=False)
d_dict = agg_eidx_dict(d_files)

d_index = []
d_train_bacc = []
d_train_ppv = []
d_train_roc = []

d_val_bacc = []
d_val_ppv = []
d_val_roc = []

d_test_bacc = []
d_test_ppv = []
d_test_roc = []

for key in d_dict:
    d_files_in_order = sorted(d_dict[key], key=lambda x: (int(x.split('_')[3].split('.')[0]), x.split('_')[2]), reverse=True)
    d_index.append(key)
    train_bacc = []
    train_ppv = []
    train_roc = []
    
    val_bacc = []
    val_ppv = []
    val_roc = []
    
    test_bacc = []
    test_ppv = []
    test_roc = []
    for file in d_files_in_order:
        with open(os.path.join(dynamic_dir, file), 'rb') as f:
            d_result_data = joblib.load(f)
        clc = 'cat'
        train_bacc.append(d_result_data[clc]['train_score_avg']['bacc'])
        train_ppv.append(d_result_data[clc]['train_score_avg']['ppv'])
        train_roc.append(d_result_data[clc]['train_score_avg']['roc'])
        
        val_bacc.append(d_result_data[clc]['val_score_avg']['bacc'])
        val_ppv.append(d_result_data[clc]['val_score_avg']['ppv'])
        val_roc.append(d_result_data[clc]['val_score_avg']['roc'])
        
        test_bacc.append(d_result_data[clc]['test_results']['bacc'])
        test_ppv.append(d_result_data[clc]['test_results']['ppv'])
        test_roc.append(d_result_data[clc]['test_results']['roc'])
    
            
    # all_train_bacc.append(train_bacc)
    # all_train_ppv.append(train_ppv)
    # all_train_roc.append(train_roc)
    
    
    # all_val_bacc.append(val_bacc)
    # all_val_ppv.append(val_ppv)
    # all_val_roc.append(val_roc)

    # all_test_bacc.append(test_bacc)
    # all_test_ppv.append(test_ppv)
    # all_test_roc.append(test_roc)
    d_train_bacc.append((np.mean(train_bacc), np.std(train_bacc, ddof=1)))
    d_train_ppv.append((np.mean(train_ppv), np.std(train_ppv, ddof=1)))
    d_train_roc.append((np.mean(train_roc), np.std(train_roc, ddof=1)))
    
    
    d_val_bacc.append((np.mean(val_bacc), np.std(val_bacc, ddof=1)))
    d_val_ppv.append((np.mean(val_ppv), np.std(val_ppv, ddof=1)))
    d_val_roc.append((np.mean(val_roc), np.std(val_roc, ddof=1)))

    d_test_bacc.append((np.mean(test_bacc), np.std(test_bacc, ddof=1)))
    d_test_ppv.append((np.mean(test_ppv), np.std(test_ppv, ddof=1)))
    d_test_roc.append((np.mean(test_roc), np.std(test_roc, ddof=1)))

# %%
fig, ax = plt.subplots(figsize=(22,8), dpi=160)
# plt.errorbar(comb_index, list(map(lambda x:x[0], comb_test_bacc)), yerr=list(map(lambda x:x[1], comb_test_bacc)), fmt='-x', capsize=5, label="Combine Static and Dynamic", alpha=0.5)
plt.errorbar(all_index, list(map(lambda x:x[0], all_test_bacc)), yerr=list(map(lambda x:x[1], all_test_bacc)), fmt='-x', capsize=5, label="All feats combined", alpha=0.5)
plt.errorbar(s_index, list(map(lambda x:x[0], s_test_bacc)), yerr=list(map(lambda x:x[1], s_test_bacc)), fmt='-x', capsize=5, label="Static feats combined", alpha=0.5)
plt.errorbar(d_index, list(map(lambda x:x[0], d_test_bacc)), yerr=list(map(lambda x:x[1], d_test_bacc)), fmt='-x', capsize=5, label="Dynamic feats combined", alpha=0.5)

plt.ylabel('Accuracy')
plt.xlabel('Events')
plt.title("Accuracy across events with mean/std over folds")
plt.legend()
fig.savefig("error.png")
plt.show()

# %%
static_files = [file for file in os.listdir(static_dir) if file.startswith('static') and file.endswith('.joblib')] 
dynamic_files = [file for file in os.listdir(dynamic_dir) if file.startswith('dynamic') and file.endswith('.joblib')] 
comb_files = [file for file in os.listdir(comb_dir) if file.startswith('comb') and file.endswith('.joblib')] 
all_files = [file for file in os.listdir(all_dir) if file.startswith('all') and file.endswith('.joblib')] 
# s_static = sorted(static_files, key = lambda x: (int(x.split('_')[1]), int(x.split('_')[-1].split('.')[0]), x.split('_')[2]), reverse=True)
s_static = sorted(static_files, key = lambda x: (int(x.split('_')[2]), int(x.split('_')[-1].split('.')[0])), reverse=False)
s_dict = agg_eidx_dict(s_static)

s_dynamic = sorted(dynamic_files, key = lambda x: (int(x.split('_')[2]), int(x.split('_')[-1].split('.')[0])), reverse=False)
d_dict = agg_eidx_dict(s_dynamic)
comb_dict =
# Out:
#   Cell In[21], line 11
#     comb_dict =
#                 ^
# SyntaxError: invalid syntax

# %%
index = []
static_train_bacc = []
static_train_ppv = []
static_train_roc = []

static_val_bacc = []
static_val_ppv = []
static_val_roc = []

static_test_bacc = []
static_test_ppv = []
static_test_roc = []

dynamic_train_bacc = []
dynamic_train_ppv = []
dynamic_train_roc = []

dynamic_val_bacc = []
dynamic_val_ppv = []
dynamic_val_roc = []

dynamic_test_bacc = []
dynamic_test_ppv = []
dynamic_test_roc = []
for key in s_dict:
    s_files_in_order = sorted(s_dict[key], key=lambda x: (int(x.split('_')[3].split('.')[0]), x.split('_')[2]), reverse=True)
    d_files_in_order = sorted(d_dict[key], key=lambda x: (int(x.split('_')[3].split('.')[0]), x.split('_')[2]), reverse=True)
    if len(s_files_in_order) == 0 or len(d_files_in_order)==0:
        print(f"Skipping {key} ")
        continue
    if len(s_files_in_order) != len(d_files_in_order):
        break
    
    sd_files = list(zip(s_files_in_order, d_files_in_order))


    static, dynamic =  sd_files[0]
    # for static, dynamic in sd_files:
    try:
        with open(os.path.join(static_dir, static), 'rb') as f:
            st_data = joblib.load(f)
            
        with open(os.path.join(dynamic_dir, dynamic), 'rb') as f:
            dyn_data = joblib.load(f)
    
        with open(os.path.join(comb_dir, dynamic), 'rb') as f:
            dyn_data = joblib.load(f)
    
        with open(os.path.join(all_dir, dynamic), 'rb') as f:
            dyn_data = joblib.load(f)
    except Exception as e:
        print(f"Skipping {key} ")
        continue

    print(f"Processing {key}")

    

    index.append(int(static.split('_')[2]))
    # for clc in st_data:
    clc = 'cat'
    static_train_bacc.append(st_data[clc]['train_score_avg']['bacc'])
    static_train_ppv.append(st_data[clc]['train_score_avg']['ppv'])
    static_train_roc.append(st_data[clc]['train_score_avg']['roc'])
    
    static_val_bacc.append(st_data[clc]['val_score_avg']['bacc'])
    static_val_ppv.append(st_data[clc]['val_score_avg']['ppv'])
    static_val_roc.append(st_data[clc]['val_score_avg']['roc'])

    static_test_bacc.append(st_data[clc]['test_results']['bacc'])
    static_test_ppv.append(st_data[clc]['test_results']['ppv'])
    static_test_roc.append(st_data[clc]['test_results']['roc'])
        
        
        # static_train_scores = st_data[clc]['train_score_avg']
        # static_val_scores = st_data[clc]['val_score_avg']
        # static_test_scores = st_data[clc]['test_results']
    
    # for clc in dyn_data:
    dynamic_train_bacc.append(dyn_data[clc]['train_score_avg']['bacc'])
    dynamic_train_ppv.append(dyn_data[clc]['train_score_avg']['ppv'])
    dynamic_train_roc.append(dyn_data[clc]['train_score_avg']['roc'])
    
    dynamic_val_bacc.append(dyn_data[clc]['val_score_avg']['bacc'])
    dynamic_val_ppv.append(dyn_data[clc]['val_score_avg']['ppv'])
    dynamic_val_roc.append(dyn_data[clc]['val_score_avg']['roc'])

    dynamic_test_bacc.append(dyn_data[clc]['test_results']['bacc'])
    dynamic_test_ppv.append(dyn_data[clc]['test_results']['ppv'])
    dynamic_test_roc.append(dyn_data[clc]['test_results']['roc'])
# Out:
# Skipping 6
# Skipping 8
# Skipping 9
# Skipping 10
# Skipping 11
# Skipping 12
# Skipping 13
# Skipping 14
# Skipping 15
# Skipping 16
# Skipping 17
# Skipping 18
# Skipping 19
# Skipping 20
# Skipping 21
# Skipping 22
# Skipping 23
# Skipping 24
# Skipping 25
# Skipping 26
# Skipping 27
# Skipping 28
# Skipping 29
# Skipping 30
# Skipping 31
# Skipping 32
# Skipping 33
# Skipping 34
# Skipping 35
# Skipping 36
# Skipping 37
# Skipping 38
# Skipping 39
# Skipping 40
# Skipping 41
# Skipping 42
# Skipping 43
# Skipping 44
# Skipping 45
# Skipping 46
# Skipping 47
# Skipping 48
# Skipping 49
# Skipping 50
# Skipping 51
# Skipping 52
# Skipping 53
# Skipping 54
# Skipping 55
# Skipping 56
# Skipping 57
# Skipping 58
# Skipping 59
# Skipping 60
# Skipping 61
# Skipping 62
# Skipping 63
# Skipping 64
# Skipping 65
# Skipping 66
# Skipping 67
# Skipping 68
# Skipping 69
# Skipping 70
# Skipping 71
# Skipping 72
# Skipping 73
# Skipping 74
# Skipping 75
# Skipping 76
# Skipping 77
# Skipping 78
# Skipping 79
# Skipping 80
# Skipping 81
# Skipping 82
# Skipping 178
# Skipping 179
# Skipping 180
# Skipping 181
# Skipping 182
# Skipping 183
# Skipping 184
# Skipping 185
# Skipping 186
# Skipping 187
# Skipping 188
# Skipping 189
# Skipping 190
# Skipping 191
# Skipping 192
# Skipping 193
# Skipping 194
# Skipping 195
# Skipping 196
# Skipping 197
# Skipping 198
# Skipping 199
# Skipping 200
# Skipping 201
# Skipping 202
# Skipping 203
# Skipping 204
# Skipping 205
# Skipping 206
# Skipping 207
# Skipping 208
# Skipping 209
# Skipping 210
# Skipping 211
# Skipping 212
# Skipping 213
# Skipping 214
# Skipping 215
# Skipping 216
# Skipping 217
# Skipping 218
# Skipping 219
# Skipping 220
# Skipping 221
# Skipping 222
# Skipping 223
# Skipping 224
# Skipping 225
# Skipping 226
# Skipping 227
# Skipping 228
# Skipping 229
# Skipping 230
# Skipping 231
# Skipping 232
# Skipping 233
# Skipping 234
# Skipping 235
# Skipping 236
# Skipping 237
# Skipping 238
# Skipping 239
# Skipping 240
# Skipping 241
# Skipping 242
# Skipping 243
# Skipping 244
# Skipping 245
# Skipping 246
# Skipping 247
# Skipping 248
# Skipping 249
# Skipping 250

# %%
static_train_bacc
# Out:
# []

# %%
fig, axes = plt.subplots(3,3, figsize=(24, 12))
# for i in range(3):
    # for j in range(3):
        # all_range = np.arange(np.min(index), np.max(index)+1)
        # axes[i][j].plot(all_range, [0]*len(all_range))

axes[0][0].scatter(index, static_train_bacc)
axes[0][1].scatter(index, static_train_ppv)
axes[0][2].scatter(index, static_train_roc)

axes[1][0].scatter(index, static_val_bacc)
axes[1][1].scatter(index, static_val_ppv)
axes[1][2].scatter(index, static_val_roc)

axes[2][0].scatter(index, static_test_bacc)
axes[2][1].scatter(index, static_test_ppv)
axes[2][2].scatter(index, static_test_roc)

# %%
fig, axes = plt.subplots(3,3, figsize=(24, 12))

axes[0][0].scatter(index, dynamic_train_bacc)
axes[0][1].scatter(index, dynamic_train_ppv)
axes[0][2].scatter(index, dynamic_train_roc)

axes[1][0].scatter(index, dynamic_val_bacc)
axes[1][1].scatter(index, dynamic_val_ppv)
axes[1][2].scatter(index, dynamic_val_roc)

axes[2][0].scatter(index, dynamic_test_bacc)
axes[2][1].scatter(index, dynamic_test_ppv)
axes[2][2].scatter(index, dynamic_test_roc)

# %%
fig, axes = plt.subplots(3,3, figsize=(24, 12))

axes[0][0].scatter(index, dynamic_train_bacc)
axes[0][1].scatter(index, dynamic_train_ppv)
axes[0][2].scatter(index, dynamic_train_roc)

axes[1][0].scatter(index, dynamic_val_bacc)
axes[1][1].scatter(index, dynamic_val_ppv)
axes[1][2].scatter(index, dynamic_val_roc)

axes[2][0].scatter(index, dynamic_test_bacc)
axes[2][1].scatter(index, dynamic_test_ppv)
axes[2][2].scatter(index, dynamic_test_roc)
