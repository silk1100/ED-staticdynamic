# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import re
from plotly.offline import iplot
from collections import defaultdict
import json

# %%
df = pd.read_csv('/work/InternalMedicine/s223850/ED-StaticDynamic/raw_data/ED Events - 12.21.23.csv')
df['Arrived_Time'] = pd.to_datetime(df['Arrived_Time'])
df['Calculated_DateTime'] = pd.to_datetime(df['Calculated_DateTime'])
df = df.sort_values(by='Calculated_DateTime')

# %%
df = df[df['Calculated_DateTime'].dt.year>=2021]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17304895 entries, 3024075 to 17277846
# Data columns (total 31 columns):
#  #   Column                                                                  Dtype
# ---  ------                                                                  -----
#  0   PAT_ENC_CSN_ID                                                          int64
#  1   PAT_MRN_ID                                                              int64
#  2   PAT_ID                                                                  object
#  3   Ethnicity                                                               object
#  4   FirstRace                                                               object
#  5   MultiRacial                                                             int64
#  6   Sex                                                                     object
#  7   Arrived_Time                                                            datetime64[ns]
#  8   ED_Disposition                                                          object
#  9   Admitted_YN                                                             object
#  10  Patient_Age                                                             float64
#  11  Acuity_Level                                                            object
#  12  Means_Of_Arrival                                                        object
#  13  Chief_Complaint                                                         object
#  14  Chief_Complaint_All                                                     object
#  15  Count_of_Chief_Complaints                                               int64
#  16  Calculated_DateTime                                                     datetime64[ns]
#  17  Coverage_Financial_Class_Grouper                                        object
#  18  Has Completed Appt in Last Seven Days                                   object
#  19  Has Hospital Encounter in Last Seven Days                               object
#  20  Number of Inpatient Admissions in the last 30 Days                      int64
#  21  Number of past appointments in last 60 days                             int64
#  22  Number of past inpatient admissions over ED visits in last three years  int64
#  23  Type                                                                    object
#  24  EVENT_NAME                                                              object
#  25  ED_Location_YN                                                          object
#  26  Order_Status                                                            object
#  27  Result_Flag                                                             object
#  28  Primary_DX_Name                                                         object
#  29  Primary_DX_First_ICD10                                                  object
#  30  Primary_DX_ICD10                                                        object
# dtypes: datetime64[ns](2), float64(1), int64(7), object(21)
# memory usage: 4.1+ GB

# %%
df_admi = df[df['ED_Disposition']=='Admitted']
df_disch = df[df['ED_Disposition']=='Discharged']
df_all = pd.concat([df_admi, df_disch], axis=0, ignore_index=True)

# %%
(df['Patient_Age'] == 'Unknown').sum()
# Out:
# 0

# %% [markdown]
# ### Create a test raw db

# %%
r_subj = np.random.choice(df_all['PAT_ENC_CSN_ID'].unique(), 1000, replace=False)

# %%
df_random = df.loc[df['PAT_ENC_CSN_ID'].isin(r_subj)]

# %%
df_random.shape
# Out:
# (150964, 31)

# %%
df_random.to_csv('/work/InternalMedicine/s223850/ED-StaticDynamic/raw_data/ED Events - 12.21.23_random.csv')

# %%
#======================================================

# %%
df[df['PAT_ENC_CSN_ID']==687744741]
# Out:
# Empty DataFrame
# Columns: [PAT_ENC_CSN_ID, PAT_MRN_ID, PAT_ID, Ethnicity, FirstRace, MultiRacial, Sex, Arrived_Time, ED_Disposition, Admitted_YN, Patient_Age, Acuity_Level, Means_Of_Arrival, Chief_Complaint, Chief_Complaint_All, Count_of_Chief_Complaints, Calculated_DateTime, Coverage_Financial_Class_Grouper, Has Completed Appt in Last Seven Days, Has Hospital Encounter in Last Seven Days, Number of Inpatient Admissions in the last 30 Days, Number of past appointments in last 60 days, Number of past inpatient admissions over ED visits in last three years, Type, EVENT_NAME, ED_Location_YN, Order_Status, Result_Flag, Primary_DX_Name, Primary_DX_First_ICD10, Primary_DX_ICD10]
# Index: []
#
# [0 rows x 31 columns]

# %%
# Admissions without admission orders
group_admi = df_admi.groupby('PAT_ENC_CSN_ID')
pat_id_list = []
for pid, df_g in group_admi:
    mask_admi = df_g['Type'] == 'Order - Admission'
    if mask_admi.sum()==0:
        pat_id_list.append(pid)

# %%
# Discharges without discharge orders orders
group_disch = df_disch.groupby('PAT_ENC_CSN_ID')
pat_id_list_disc = []
for pid, df_g in group_disch:
    mask_disch = df_g['Type'] == 'Order - Discharge'
    if mask_disch.sum()==0:
        pat_id_list_disc.append(pid)

# %%
len(pat_id_list)/df_admi['PAT_ENC_CSN_ID'].nunique()
# Out:
# 0.006760008750820389

# %%
len(pat_id_list_disc)/df_disch['PAT_ENC_CSN_ID'].nunique()
# Out:
# 0.9971057134176567

# %%
pd.DataFrame(pat_id_list, columns=['PAT_ENC_CSN_ID']).to_csv('admit_patient_without_OrderAdmission.csv')

# %%
pd.DataFrame(pat_id_list_disc, columns=['PAT_ENC_CSN_ID']).to_csv('disch_patient_without_OrderDischarge.csv')

# %%
df[df['PAT_ENC_CSN_ID']==pat_id_list_disc[-2]].tail(60)
# Out:
#           PAT_ENC_CSN_ID  PAT_MRN_ID    PAT_ID            Ethnicity FirstRace  \
# 882832         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 1353039        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 16304263       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 1353038        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 16304262       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 11577183       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 11577184       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 11577185       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 11577186       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 1481140        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 1481139        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 1481141        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 11577242       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 10143506       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 16304261       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 869063         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 12760144       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 11577243       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 7520959        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 6414003        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 12760143       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 7520960        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 11577244       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 17290846       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 489113         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 17290847       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 411010         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 17297037       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 6414004        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 457709         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 7520961        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 2096544        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 411011         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 11577245       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 3034117        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 17290849       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 1481142        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 869064         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 11577246       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 17302004       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 17286345       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 3033938        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 454632         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 11577247       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 395215         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 3070327        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 17286577       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 3034122        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 3033941        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 3070328        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 268260         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 3070479        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 3070478        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 17286580       695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 3070480        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 268263         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 268264         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 268266         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 3070483        695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
# 395218         695159895    93148851  Z5607287  Non-Hispanic/Latino     Asian
#
#           MultiRacial     Sex        Arrived_Time ED_Disposition  \
# 882832              0  Female 2023-12-20 19:48:28     Discharged
# 1353039             0  Female 2023-12-20 19:48:28     Discharged
# 16304263            0  Female 2023-12-20 19:48:28     Discharged
# 1353038             0  Female 2023-12-20 19:48:28     Discharged
# 16304262            0  Female 2023-12-20 19:48:28     Discharged
# 11577183            0  Female 2023-12-20 19:48:28     Discharged
# 11577184            0  Female 2023-12-20 19:48:28     Discharged
# 11577185            0  Female 2023-12-20 19:48:28     Discharged
# 11577186            0  Female 2023-12-20 19:48:28     Discharged
# 457709                                                    0
# 7520961                                                   0
# 2096544                                                   0
# 411011                                                    0
# 11577245                                                  0
# 3034117                                                   0
# 17290849                                                  0
# 1481142                                                   0
# 869064                                                    0
# 11577246                                                  0
# 17302004                                                  0
# 17286345                                                  0
# 3033938                                                   0
# 454632                                                    0
# 11577247                                                  0
# 395215                                                    0
# 3070327                                                   0
# 17286577                                                  0
# 3034122                                                   0
# 3033941                                                   0
# 3070328                                                   0
# 268260                                                    0
# 3070479                                                   0
# 3070478                                                   0
# 17286580                                                  0
# 3070480                                                   0
# 268263                                                    0
# 268264                                                    0
# 268266                                                    0
# 3070483                                                   0
# 395218                                                    0
#
#                         Type  \
# 882832    Lab Order - Result
# 1353039   Lab Order - Result
# 16304263  Lab Order - Result
# 1353038   Lab Order - Result
# 16304262  Lab Order - Result
# 11577183  Lab Order - Result
# 11577184  Lab Order - Result
# 11577185  Lab Order - Result
# 11577186  Lab Order - Result
# 1481140   Lab Order - Result
# 1481139   Lab Order - Result
# 1481141   Lab Order - Result
# 11577242  Lab Order - Result
# 10143506               Event
# 16304261  Lab Order - Result
# 869063           Order - Lab
# 12760144  Lab Order - Result
# 11577243  Lab Order - Result
# 7520959   Lab Order - Result
# 6414003   Lab Order - Result
# 12760143  Lab Order - Result
# 7520960          Order - Lab
# 11577244  Lab Order - Result
# 17290846               Event
# 489113                 Event
# 17290847               Event
# 411010                 Event
# 17297037               Event
# 6414004      Order - Consult
# 457709                 Event
# 7520961      Order - Consult
# 2096544                Event
# 411011                 Event
# 11577245     Order - Imaging
# 3034117                Event
# 17290849               Event
# 1481142      Order - Consult
# 869064       Order - Consult
# 11577246     Order - Consult
# 17302004               Event
# 17286345               Event
# 3033938                Event
# 454632                 Event
# 11577247     Order - Imaging
# 395215                 Event
# 3070327                Event
# 17286577               Event
# 3034122                Event
# 3033941                Event
# 3070328                Event
# 268260                 Event
# 3070479                Event
# 3070478                Event
# 17286580               Event
# 3070480                Event
# 268263                 Event
# 268264                 Event
# 268266                 Event
# 3070483                Event
# 395218                 Event
#
#                                                  EVENT_NAME ED_Location_YN  \
# 882832                           CALCIUM (ALBUMIN ADJUSTED)            Yes
# 1353039                                                 BUN            Yes
# 16304263                                      TOTAL PROTEIN            Yes
# 1353038                                           ANION GAP            Yes
# 16304262                                           GLOBULIN            Yes
# 11577183                                           ALK PHOS            Yes
# 11577184                                                ALT            Yes
# 11577185                                                AST            Yes
# 11577186                                   BILIRUBIN, TOTAL            Yes
# 1481140                                             ALBUMIN            Yes
# 1481139                                           A/G RATIO            Yes
# 1481141                                           POTASSIUM            Yes
# 11577242                                         CREATININE            Yes
# 10143506                                ED Lactate Resulted            Yes
# 16304261                                                CO2            Yes
# 869063                 CMPL (COMPREHENSIVE METABOLIC PANEL)            Yes
# 12760144                                    EGFR CKD EPI CR            Yes
# 11577243                                             SODIUM            Yes
# 7520959                                            CHLORIDE            Yes
# 6414003                                             GLUCOSE            Yes
# 12760143                                            CALCIUM            Yes
# 12760143           NaN      Normal                      RLQ abdominal pain
# 7520960      Completed    Resulted                      RLQ abdominal pain
# 11577244           NaN        High                      RLQ abdominal pain
# 17290846           NaN         NaN                      RLQ abdominal pain
# 489113             NaN         NaN                      RLQ abdominal pain
# 17290847           NaN         NaN                      RLQ abdominal pain
# 411010             NaN         NaN                      RLQ abdominal pain
# 17297037           NaN         NaN                      RLQ abdominal pain
# 6414004       Canceled     Ordered                      RLQ abdominal pain
# 457709             NaN         NaN                      RLQ abdominal pain
# 7520961       Canceled     Ordered                      RLQ abdominal pain
# 2096544            NaN         NaN                      RLQ abdominal pain
# 411011             NaN         NaN                      RLQ abdominal pain
# 11577245      Canceled     Ordered                      RLQ abdominal pain
# 3034117            NaN         NaN                      RLQ abdominal pain
# 17290849           NaN         NaN                      RLQ abdominal pain
# 1481142       Canceled    Canceled                      RLQ abdominal pain
# 869064        Canceled     Ordered                      RLQ abdominal pain
# 11577246      Canceled    Canceled                      RLQ abdominal pain
# 17302004           NaN         NaN                      RLQ abdominal pain
# 17286345           NaN         NaN                      RLQ abdominal pain
# 3033938            NaN         NaN                      RLQ abdominal pain
# 454632             NaN         NaN                      RLQ abdominal pain
# 11577247      Canceled    Canceled                      RLQ abdominal pain
# 395215             NaN         NaN                      RLQ abdominal pain
# 3070327            NaN         NaN                      RLQ abdominal pain
# 17286577           NaN         NaN  Pregnancy of unknown anatomic location
# 3034122            NaN         NaN  Pregnancy of unknown anatomic location
# 3033941            NaN         NaN  Pregnancy of unknown anatomic location
# 3070328            NaN         NaN  Pregnancy of unknown anatomic location
# 268260             NaN         NaN  Pregnancy of unknown anatomic location
# 3070479            NaN         NaN  Pregnancy of unknown anatomic location
# 3070478            NaN         NaN  Pregnancy of unknown anatomic location
# 17286580           NaN         NaN  Pregnancy of unknown anatomic location
# 3070480            NaN         NaN  Pregnancy of unknown anatomic location
# 268263             NaN         NaN  Pregnancy of unknown anatomic location
# 268264             NaN         NaN  Pregnancy of unknown anatomic location
# 268266             NaN         NaN  Pregnancy of unknown anatomic location
# 3070483            NaN         NaN  Pregnancy of unknown anatomic location
# 395218             NaN         NaN  Pregnancy of unknown anatomic location
#
#          Primary_DX_First_ICD10 Primary_DX_ICD10
# 882832                   R10.31           R10.31
# 1353039                  R10.31           R10.31
# 16304263                 R10.31           R10.31
# 1353038                  R10.31           R10.31
# 16304262                 R10.31           R10.31
# 11577183                 R10.31           R10.31
# 11577184                 R10.31           R10.31
# 11577185                 R10.31           R10.31
# 11577186                 R10.31           R10.31
# 1481140                  R10.31           R10.31
# 1481139                  R10.31           R10.31
# 1481141                  R10.31           R10.31
# 11577242                 R10.31           R10.31
# 10143506                 R10.31           R10.31
# 16304261                 R10.31           R10.31
# 869063                   R10.31           R10.31
# 12760144                 R10.31           R10.31
# 11577243                 R10.31           R10.31
# 7520959                  R10.31           R10.31
# 6414003                  R10.31           R10.31
# 12760143                 R10.31           R10.31
# 7520960                  R10.31           R10.31
# 11577244                 R10.31           R10.31
# 17290846                 R10.31           R10.31
# 489113                   R10.31           R10.31
# 17290847                 R10.31           R10.31
# 411010                   R10.31           R10.31
# 17297037                 R10.31           R10.31
# 6414004                  R10.31           R10.31
# 457709                   R10.31           R10.31
# 7520961                  R10.31           R10.31
# 2096544                  R10.31           R10.31
# 411011                   R10.31           R10.31
# 11577245                 R10.31           R10.31
# 3034117                  R10.31           R10.31
# 17290849                 R10.31           R10.31
# 1481142                  R10.31           R10.31
# 869064                   R10.31           R10.31
# 11577246                 R10.31           R10.31
# 17302004                 R10.31           R10.31
# 17286345                 R10.31           R10.31
# 3033938                  R10.31           R10.31
# 454632                   R10.31           R10.31
# 11577247                 R10.31           R10.31
# 395215                   R10.31           R10.31
# 3070327                  R10.31           R10.31
# 17286577               O36.80X0         O36.80X0
# 3034122                O36.80X0         O36.80X0
# 3033941                O36.80X0         O36.80X0
# 3070328                O36.80X0         O36.80X0
# 268260                 O36.80X0         O36.80X0
# 3070479                O36.80X0         O36.80X0
# 3070478                O36.80X0         O36.80X0
# 17286580               O36.80X0         O36.80X0
# 3070480                O36.80X0         O36.80X0
# 268263                 O36.80X0         O36.80X0
# 268264                 O36.80X0         O36.80X0
# 268266                 O36.80X0         O36.80X0
# 3070483                O36.80X0         O36.80X0
# 395218                 O36.80X0         O36.80X0
#
# [60 rows x 31 columns]

# %%
df_all[f'EVENT_NAME_NORM'] = df_all['EVENT_NAME'].apply(lambda x: re.sub(r'[^a-zA-Z0-9_]', '', x)).str.lower()
df_all = df_all.sort_values(by='Calculated_DateTime')

# %%
def get_target_flags(raw_file_path, event_col='EVENT_NAME', grb_col='Admitted_YN', flag='consu', normalize_text=True, corr_threshold=0.7):

    df_raw = raw_file_path
    if normalize_text:
        # df_raw[f'{event_col}_NORM'] = df_raw[event_col].apply(lambda x: re.sub(r'[^a-zA-Z0-9_]', '', x)).str.lower()
        event_col = f'{event_col}_NORM'

    flag_df = df_raw.loc[df_raw[event_col].str.lower().str.contains(flag), [event_col, grb_col]]
    flag_grb = flag_df.groupby(grb_col).value_counts()

    data = pd.DataFrame(0, index=flag_df[event_col].unique(), columns=flag_df[grb_col].unique())
    for (flag, event), value in flag_grb.items():
        data.loc[event, flag] = value
    
    data['total'] = data.sum(axis=1)
    # TODO: This is a hardcoded value of the target params and need to be changed manually
    data['perc_pos'] = data['Admitted']/data['total']

    target_events = data.loc[(data['perc_pos']>=corr_threshold)|(data['perc_pos']<=(1-corr_threshold))].index
    return target_events, data

# %%
admi_flags, df_admi_flags  = get_target_flags(df_all, event_col='EVENT_NAME', grb_col='ED_Disposition', flag='consu', normalize_text=True, corr_threshold=0.7)

# %%
admi_flags_times = defaultdict(list) # in minutes
df_admi = df_all[df_all['ED_Disposition']=='Admitted']
group_admi = df_admi.groupby('PAT_ENC_CSN_ID')

for grb, df_grb in group_admi:
    admi_mask = df_grb['EVENT_NAME_NORM'].isin(admi_flags)
    if admi_mask.sum() == 0:
        continue
    mask_admission = df_grb['Type'] == 'Order - Admission'
    if mask_admission.sum() > 0:
        admi_time = df_grb.iloc[np.where(mask_admission)[0][0]]['Calculated_DateTime']
        for idx, row in df_grb[admi_mask].iterrows():
            admi_flags_times[row['EVENT_NAME_NORM']].append(('admission', grb, (admi_time-row['Calculated_DateTime']).total_seconds()/60))

# %%
flag_time_dict = defaultdict(list)
for flag, data_list in admi_flags_times.items():
    for d in data_list:
        flag_time_dict[flag].append(d[-1])

# %%
for flag, timelist in flag_time_dict.items():
    print(f'{flag} has min time: {np.min(timelist)}, median time: {np.median(timelist)}, average time {np.mean(timelist)}, std time {np.std(timelist, ddof=1)}, and max time: {np.max(timelist)} ..')
# Out:
# ippcconsulttoophthalmology has min time: -677.0, median time: 231.5, average time 253.26315789473685, std time 230.85810935363207, and max time: 1288.0 ..
# consultorderedophthalmology has min time: -92.55, median time: 244.14166666666665, average time 282.4245575221239, std time 197.50653930358266, and max time: 1287.0 ..
# consulttrackingstarted has min time: -1181.5833333333333, median time: 39.9, average time 111.56772399516649, std time 259.28983303712045, and max time: 9900.683333333332 ..
# pharmacykineticsconsultvancomycin has min time: -1040.0, median time: 113.0, average time 128.87946555481852, std time 178.03412111954157, and max time: 1615.0 ..
# ippcconsulttohematology has min time: -1151.0, median time: 45.0, average time 61.30362116991643, std time 188.74998706192963, and max time: 1764.0 ..
# consultorderedhemoncattending has min time: -61.75, median time: 77.28333333333333, average time 124.0965721040189, std time 157.27162447372376, and max time: 1763.3333333333333 ..
# ednuredconsultspecify has min time: -1649.0, median time: 24.0, average time 80.63851148125869, std time 273.3298681781328, and max time: 9907.0 ..
# hospitalistadmitsconsultcalled has min time: -752.5, median time: 16.05, average time 32.34052856241835, std time 60.754378254096686, and max time: 2157.65 ..
# consultorderedpulmonary has min time: -274.5833333333333, median time: 75.43333333333334, average time 94.80806034988848, std time 95.67491390490724, and max time: 1730.7333333333333 ..
# ippcconsulttocardiology has min time: -589.0, median time: 57.0, average time 77.72864637985309, std time 145.18613529963147, and max time: 3159.0 ..
# consultorderedcardiologyconsults has min time: -303.26666666666665, median time: 88.91666666666667, average time 121.66427511133102, std time 141.38587385674649, and max time: 3158.4166666666665 ..
# cardiologyconsultscalled has min time: -305.8833333333333, median time: 82.16666666666666, average time 114.59085492227979, std time 141.2740420038882, and max time: 3156.95 ..
# ippcconsulttokidneypanctransplant has min time: -997.0, median time: 50.0, average time 69.72295514511873, std time 160.6928937815202, and max time: 1897.0 ..
# ipconsulttolivertransplant has min time: -296.0, median time: 65.0, average time 91.81649484536082, std time 110.93415018726718, and max time: 548.0 ..
# consultorderedcuhkidneypancreastransplantconsult has min time: -78.68333333333334, median time: 64.86666666666667, average time 100.07705223880598, std time 149.4852878122188, and max time: 1896.15 ..
# livertransplantconsultcalled has min time: -62.18333333333333, median time: 63.974999999999994, average time 101.41283643892339, std time 103.32264271145681, and max time: 542.8166666666667 ..
# ippcconsulttochf has min time: -295.0, median time: 61.5, average time 79.41780821917808, std time 90.01377089688178, and max time: 642.0 ..
# pharmacykineticsconsultamikacin has min time: -255.0, median time: -130.0, average time -42.142857142857146, std time 230.04668263306078, and max time: 420.0 ..
# interventionalradiologymskjointconsultordered has min time: 14.533333333333333, median time: 71.28333333333333, average time 117.00833333333334, std time 110.27167245504054, and max time: 360.93333333333334 ..
# interventionalradiologymskjointconsultcalled has min time: 12.0, median time: 62.7, average time 97.46904761904761, std time 119.32554072499384, and max time: 359.46666666666664 ..
# interventionalradiologylpspineconsultordered has min time: 5.65, median time: 86.73333333333333, average time 124.27000000000001, std time 116.29909702252193, and max time: 355.85 ..
# ippcconsulttoorthopaedicsspine has min time: -1043.0, median time: 0.0, average time 64.65555555555555, std time 266.96947437804175, and max time: 699.0 ..
# ippcconsulttopsychologycuh has min time: -275.0, median time: -58.0, average time 218.47368421052633, std time 751.831938107111, and max time: 2267.0 ..
# cancersupportservicesclinicalprogramcoordinationreferralconsult has min time: 189.0, median time: 189.0, average time 189.0, std time nan, and max time: 189.0 ..
# consultnephrologytransplantforusebyedprovidersonly has min time: 13.0, median time: 50.0, average time 90.83333333333333, std time 99.57348436144427, and max time: 368.0 ..
# bmtblymmyecartconsultrecalled has min time: 3.4166666666666665, median time: 3.4166666666666665, average time 3.4166666666666665, std time nan, and max time: 3.4166666666666665 ..
# consultorderedneurologyzale has min time: 123.6, median time: 182.1, average time 182.1, std time 82.73149339882606, and max time: 240.6 ..
# neurozaleconsultcalled has min time: 118.46666666666667, median time: 169.69166666666666, average time 169.69166666666666, std time 72.44308973256179, and max time: 220.91666666666666 ..
# consulttokidneypanctransplant has min time: -112.0, median time: -73.5, average time -73.5, std time 54.44722215136416, and max time: -35.0 ..
# pulmonaryphconsultrecalled has min time: 4.7, median time: 41.29166666666667, average time 47.912499999999994, std time 42.53340163482847, and max time: 104.36666666666666 ..
# ippcconsulttoimmunologyallergyclinic has min time: -176.0, median time: -41.0, average time -34.625, std time 118.03865892155841, and max time: 227.0 ..
# pharmacyconsultdischargecounseling has min time: -84.0, median time: -84.0, average time -84.0, std time nan, and max time: -84.0 ..
# pharmacistconsult has min time: -119.0, median time: 189.0, average time 91.33333333333333, std time 182.308346855906, and max time: 204.0 ..
# ippcconsulttourogyn has min time: -83.0, median time: 26.0, average time 24.571428571428573, std time 116.70169542164206, and max time: 208.0 ..
# gynurogynecologyconsultordered has min time: -80.0, median time: 33.21666666666667, average time 66.35333333333332, std time 112.2829321896748, and max time: 207.73333333333332 ..
# gynurogynecologyconsultcalled has min time: -115.0, median time: 30.466666666666665, average time 51.58333333333333, std time 118.96592766184965, and max time: 195.91666666666666 ..
# consultorderedprivatephysicianaddnameincomments has min time: 25.3, median time: 60.11666666666667, average time 60.11666666666667, std time 49.238202196623256, and max time: 94.93333333333334 ..
# ippcconsulttoobmaternalfetalmedstpaul has min time: -138.0, median time: -84.0, average time -74.0, std time 69.54135460285484, and max time: 0.0 ..
# pharmacyrenalconsult has min time: -189.0, median time: -52.0, average time -74.14285714285714, std time 63.89164935375246, and max time: -3.0 ..
# cardiologyconsultscompleted has min time: 20.816666666666666, median time: 20.816666666666666, average time 20.816666666666666, std time nan, and max time: 20.816666666666666 ..
# ippcconsulttooncology has min time: -207.0, median time: -48.0, average time -17.77777777777778, std time 145.85247493424458, and max time: 158.0 ..
# ippcconsulttopainserviceacute has min time: -477.0, median time: -35.0, average time -48.05084745762712, std time 141.4309169400765, and max time: 337.0 ..
# nephrologytransplantconsultcompleted has min time: 6.116666666666666, median time: 6.116666666666666, average time 6.116666666666666, std time nan, and max time: 6.116666666666666 ..
# pharmacykineticsconsultgentamicin has min time: -81.0, median time: 2.0, average time 67.4, std time 123.3112592858684, and max time: 395.0 ..
# ippcconsulttonutritionsupportteam has min time: -257.0, median time: -53.0, average time -61.25581395348837, std time 64.49698886410117, and max time: 100.0 ..
# ipnmcconsulttodentist has min time: -129.0, median time: -5.5, average time -32.875, std time 52.047883173642546, and max time: 0.0 ..
# ippcconsulttopsychiatry has min time: -42.0, median time: -21.0, average time -21.0, std time 29.698484809834994, and max time: 0.0 ..
# orthoconsultcompleted has min time: 11.366666666666667, median time: 11.366666666666667, average time 11.366666666666667, std time nan, and max time: 11.366666666666667 ..
# ippcconsulttopulmonarymedicine has min time: -471.0, median time: -127.0, average time -139.14814814814815, std time 94.55348657432904, and max time: -45.0 ..
# ipconsulttopalliativecaresupportstaffonly has min time: -887.0, median time: -887.0, average time -887.0, std time nan, and max time: -887.0 ..
# ippcconsulttoendocrinethyroidnoduleclinic has min time: -67.0, median time: -67.0, average time -67.0, std time nan, and max time: -67.0 ..
# consultorderedhospitalistforhomehealtheval has min time: 5.166666666666667, median time: 11.091666666666669, average time 33.01666666666667, std time 48.068806779294874, and max time: 104.71666666666667 ..
# ipconsulttostructuralinterventionalcardiology has min time: -123.0, median time: -2.0, average time -29.142857142857142, std time 62.79444925423629, and max time: 58.0 ..
# consulttonephrology has min time: -185.0, median time: -28.0, average time -56.81818181818182, std time 61.83497098215246, and max time: 0.0 ..
# nephrologyesrdconsultrecalled has min time: 134.33333333333334, median time: 134.33333333333334, average time 134.33333333333334, std time nan, and max time: 134.33333333333334 ..
# pulmonaryserviceslungconsultrecalled has min time: 26.966666666666665, median time: 26.966666666666665, average time 26.966666666666665, std time nan, and max time: 26.966666666666665 ..
# cardiologyconsultsrecalled has min time: 26.033333333333335, median time: 29.25, average time 62.31333333333335, std time 52.79051287873609, and max time: 145.55 ..
# ipnurnursingconsulttobaccocessation has min time: -326.0, median time: -89.5, average time -139.125, std time 93.37549005417398, and max time: -66.0 ..
# pulmonaryphconsultresponded has min time: 10.9, median time: 10.9, average time 10.9, std time nan, and max time: 10.9 ..
# pulmonarycysticfibrosisconsultrecalled has min time: 2.7333333333333334, median time: 2.7333333333333334, average time 2.7333333333333334, std time nan, and max time: 2.7333333333333334 ..
# bmtaleukemiaconsultrecalled has min time: 70.81666666666666, median time: 70.81666666666666, average time 70.81666666666666, std time nan, and max time: 70.81666666666666 ..
# ippcconsulttohypertension has min time: -149.0, median time: -149.0, average time -149.0, std time nan, and max time: -149.0 ..
# ipnurnursingconsulttosocialwsmedical has min time: 268.0, median time: 268.0, average time 268.0, std time nan, and max time: 268.0 ..
# ippcconsulttopathology has min time: -45.0, median time: -45.0, average time -45.0, std time nan, and max time: -45.0 ..
# ippcconsulttostrokeclinic has min time: -190.0, median time: -190.0, average time -190.0, std time nan, and max time: -190.0 ..
# consultchfvadhearttxadmitsforusebyedprovidersonly has min time: 10.0, median time: 13.0, average time 23.333333333333332, std time 20.55075018906447, and max time: 47.0 ..
# liverdiseasefellowconsultrecalled has min time: 140.46666666666667, median time: 140.46666666666667, average time 140.46666666666667, std time nan, and max time: 140.46666666666667 ..
# consultkidneypancreastransplantsurgeonsforusebyedprovidersonly has min time: 198.0, median time: 198.0, average time 198.0, std time nan, and max time: 198.0 ..
# hospitalistadmitsconsultined has min time: -67.03333333333333, median time: -67.03333333333333, average time -67.03333333333333, std time nan, and max time: -67.03333333333333 ..
# ippcconsulttochfvadhearttransplant has min time: -975.0, median time: 65.0, average time 79.3220502901354, std time 100.41566928618768, and max time: 688.0 ..
# ippcconsulttolungtransplant has min time: -313.0, median time: 88.0, average time 96.45833333333333, std time 135.33127085470105, and max time: 654.0 ..
# radiologyproceduresconsultspine has min time: -186.0, median time: -141.5, average time -141.5, std time 62.932503525602726, and max time: -97.0 ..
# consulttoinfectiousdiseases has min time: -53.0, median time: -53.0, average time -53.0, std time nan, and max time: -53.0 ..
# ippharmacyhomepumptreprostinilremodulinsubcutaneousconsult has min time: -321.0, median time: 3.0, average time -42.4, std time 209.85423512524116, and max time: 213.0 ..
# ippcconsulttopsychiatrymicucuh has min time: -62.0, median time: -62.0, average time -62.0, std time nan, and max time: -62.0 ..
# hospitalistconsultcompleted has min time: 14.55, median time: 14.55, average time 14.55, std time nan, and max time: 14.55 ..
# otherconsultcompleted has min time: 1.8, median time: 1.8, average time 1.8, std time nan, and max time: 1.8 ..
# consultcardiologyconsultsforusebyedprovidersonly has min time: 18.0, median time: 104.0, average time 104.0, std time 121.62236636408618, and max time: 190.0 ..
# easyconsult has min time: -87.0, median time: 23.0, average time 83.23076923076923, std time 158.67900189069013, and max time: 373.0 ..
# ippcconsulttoinfectiousdiseasestransplant has min time: -252.0, median time: -29.5, average time -60.53333333333333, std time 74.88599764761207, and max time: 64.0 ..
# consulttotoxicology has min time: -62.0, median time: -62.0, average time -62.0, std time nan, and max time: -62.0 ..
# pharmacytechconsultadmissionmedicationhistory has min time: -744.0, median time: -30.0, average time -47.917114351496544, std time 88.44097308769786, and max time: 1307.0 ..
# ippcconsulttoneuromovementdisorder has min time: -4.0, median time: -4.0, average time -4.0, std time nan, and max time: -4.0 ..
# ippcconsulttoneuroheadache has min time: -276.0, median time: -107.0, average time -144.33333333333334, std time 117.53439212984995, and max time: -50.0 ..
# gibiliaryconsultrecalled has min time: 28.566666666666666, median time: 28.566666666666666, average time 28.566666666666666, std time nan, and max time: 28.566666666666666 ..
# orthopedicsspineconsultordered has min time: -164.95, median time: 170.69166666666666, average time 206.81054852320673, std time 176.34682487804048, and max time: 895.9666666666667 ..
# consulttoxicologyforusebyedprovidersonly has min time: 55.0, median time: 55.0, average time 55.0, std time nan, and max time: 55.0 ..
# plasticsurgeryconsultrecalled has min time: 322.5833333333333, median time: 322.5833333333333, average time 322.5833333333333, std time nan, and max time: 322.5833333333333 ..
# ippcconsulttoonocolgyzale has min time: 124.0, median time: 124.0, average time 124.0, std time nan, and max time: 124.0 ..
# ipconsulttopulmonaryemboliresponseteampert has min time: -327.0, median time: 58.5, average time 65.71428571428571, std time 143.9484034546506, and max time: 239.0 ..
# pharmacyconsultnewstartsubqtreprostenil has min time: 0.0, median time: 0.0, average time 0.0, std time nan, and max time: 0.0 ..
# consultcardiologyadmitsforusebyedprovidersonly has min time: 11.0, median time: 87.0, average time 87.0, std time 107.48023074035522, and max time: 163.0 ..
# consulttoneurosurgery has min time: 413.0, median time: 413.0, average time 413.0, std time nan, and max time: 413.0 ..
# consulttoneuroradiology has min time: 7.0, median time: 7.0, average time 7.0, std time nan, and max time: 7.0 ..
# ippcconsulttobreastcenter has min time: 22.0, median time: 22.0, average time 22.0, std time nan, and max time: 22.0 ..
# consulttovascularsurgery has min time: 278.0, median time: 278.0, average time 278.0, std time nan, and max time: 278.0 ..
# benigngynecologyconsultrecalled has min time: 0.4666666666666667, median time: 0.4666666666666667, average time 0.4666666666666667, std time nan, and max time: 0.4666666666666667 ..
# socialworkconsultcompleted has min time: 1279.1666666666667, median time: 1279.1666666666667, average time 1279.1666666666667, std time nan, and max time: 1279.1666666666667 ..
# /home2/s223850/.conda/envs/ED/lib/python3.10/site-packages/numpy/core/_methods.py:264: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /home2/s223850/.conda/envs/ED/lib/python3.10/site-packages/numpy/core/_methods.py:256: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %%
len(flag_time_dict)
# Out:
# 225

# %%
len(list(filter(lambda x: np.median(x[1])>0,flag_time_dict.items())))
# Out:
# 163

# %%
with open('consu_featurs.json', 'w') as f:
    json.dump(list(map(lambda x: x[0], list(filter(lambda x: np.median(x[1])>0,flag_time_dict.items())))),f)

# %%
t = list(map(lambda x: x[-1], admi_flags_times['hospitalistadmitsconsultcalled']))

# %%
np.argmin(t)
# Out:
# 1996

# %%
admi_flags_times['hospitalistadmitsconsultcalled'][1996]
# Out:
# ('admission', 655032721, -752.5)

# %%
pat_id_related = []
for x in admi_flags_times.items():
    for op, pid, t in x[1]:
        if pid==655032721:
            pat_id_related.append((x[0], op, pid, t))

# %%
pat_id_related
# Out:
# [('hospitalistadmitsconsultcalled', 'admission', 655032721, -752.5),
#  ('antibioticsadministerediv', 'admission', 655032721, 7.716666666666667),
#  ('antibioticsadministerediv', 'admission', 655032721, -7.466666666666667),
#  ('antibioticsadministerediv', 'admission', 655032721, -41.6),
#  ('antibioticsadministerediv', 'admission', 655032721, -88.11666666666666),
#  ('antibioticsadministerediv', 'admission', 655032721, -424.71666666666664),
#  ('antibioticsadministerediv', 'admission', 655032721, -729.75),
#  ('antibioticsadministerediv', 'admission', 655032721, -729.8333333333334),
#  ('antibioticsadministerediv', 'admission', 655032721, -889.6833333333333),
#  ('potentialadmissionbedboardnotification', 'admission', 655032721, 0.0),
#  ('admitstatuschange', 'admission', 655032721, -0.75),
#  ('uhadmitorderplaced', 'admission', 655032721, -0.75),
#  ('admissionordersreconciled', 'admission', 655032721, -62.266666666666666),
#  ('admissionordersreconciled', 'admission', 655032721, -68.55),
#  ('admitasoutpatient', 'admission', 655032721, -82.0),
#  ('hospitalistadmitsconsultordered',
#   'admission',
#   655032721,
#   16.733333333333334)]

# %%
df_pat = df_all[df_all['PAT_ENC_CSN_ID']==655032721]

# %%
df_pat[['Calculated_DateTime', 'EVENT_NAME', 'Type', 'Order_Status', 'Result_Flag']]
# Out:
#         Calculated_DateTime                    EVENT_NAME   Type Order_Status  \
# 1627889 2022-01-07 10:19:44   Emergency encounter created  Event          NaN
# 3623599 2022-01-07 10:20:04  Prev Admission Rec Generated  Event          NaN
# 6819359 2022-01-07 10:20:04  Admission FAM List Generated  Event          NaN
# 6819358 2022-01-07 10:20:04         Patient arrived in ED  Event          NaN
# 6378078 2022-01-07 10:20:04  Admission Med List Generated  Event          NaN
# ...                     ...                           ...    ...          ...
# 997639  2022-01-08 14:55:28         Pt rounding completed  Event          NaN
# 1784264 2022-01-08 14:55:28     Pt rounding timer started  Event          NaN
# 1784267 2022-01-08 15:13:26            Hospital bed ready  Event          NaN
# 3029725 2022-01-08 16:21:18                  Bed Assigned  Event          NaN
# 6400642 2022-01-08 16:25:21            Hospital bed ready  Event          NaN
#
#         Result_Flag
# 1627889         NaN
# 3623599         NaN
# 6819359         NaN
# 6819358         NaN
# 6378078         NaN
# ...             ...
# 997639          NaN
# 1784264         NaN
# 1784267         NaN
# 3029725         NaN
# 6400642         NaN
#
# [303 rows x 5 columns]

# %%
admi_mask = df_pat['EVENT_NAME_NORM'].isin(admi_flags)
admi_mask.sum()
# Out:
# 16

# %%
mask_admi = df_pat['Type'] == 'Order - Admission'
mask_admi.sum()
# Out:
# 2

# %%
df_pat[mask_admi|admi_mask][['Type', 'EVENT_NAME', 'Calculated_DateTime']]
# Out:
#                       Type                                  EVENT_NAME  \
# 8252312              Event          Hospitalist Admits Consult Ordered
# 8252313              Event                 Antibiotics Administered IV
# 6614254  Order - Admission  POTENTIAL ADMISSION BED BOARD NOTIFICATION
# 2872753              Event                         Admit Status Change
# 6647138              Event                       UH Admit Order Placed
# 6599820              Event                 Antibiotics Administered IV
# 6396697              Event                 Antibiotics Administered IV
# 6396699              Event                 Admission Orders Reconciled
# 6573966              Event                 Admission Orders Reconciled
# 774693   Order - Admission                         ADMIT AS OUTPATIENT
# 1814733              Event                 Antibiotics Administered IV
# 1633035              Event                 Antibiotics Administered IV
# 3597739              Event                 Antibiotics Administered IV
# 6382076              Event                 Antibiotics Administered IV
# 3597740              Event           Hospitalist Admits Consult Called
# 997631               Event                 Antibiotics Administered IV
#
#         Calculated_DateTime
# 8252312 2022-01-07 23:24:16
# 8252313 2022-01-07 23:33:17
# 6614254 2022-01-07 23:41:00
# 2872753 2022-01-07 23:41:45
# 6647138 2022-01-07 23:41:45
# 6599820 2022-01-07 23:48:28
# 6396697 2022-01-08 00:22:36
# 6396699 2022-01-08 00:43:16
# 6573966 2022-01-08 00:49:33
# 774693  2022-01-08 01:03:00
# 1814733 2022-01-08 01:09:07
# 1633035 2022-01-08 06:45:43
# 3597739 2022-01-08 11:50:45
# 6382076 2022-01-08 11:50:50
# 3597740 2022-01-08 12:13:30
# 997631  2022-01-08 14:30:41

# %%
admi_time = df_pat.iloc[np.where(mask_admi)[0][0]]['Calculated_DateTime']
for idx, row in df_pat[admi_mask].iterrows():
    print(row['EVENT_NAME_NORM'], " : ", (admi_time-row['Calculated_DateTime']).total_seconds()/60)
# Out:
# admitasoutpatient  :  0.0
# antibioticsadministerediv  :  -807.6833333333333
# antibioticsadministerediv  :  -342.71666666666664
# antibioticsadministerediv  :  -6.116666666666666
# admitstatuschange  :  81.25
# antibioticsadministerediv  :  -647.75
# hospitalistadmitsconsultcalled  :  -670.5
# antibioticsadministerediv  :  -647.8333333333334
# antibioticsadministerediv  :  40.4
# admissionordersreconciled  :  19.733333333333334
# admissionordersreconciled  :  13.45
# antibioticsadministerediv  :  74.53333333333333
# potentialadmissionbedboardnotification  :  82.0
# uhadmitorderplaced  :  81.25
# hospitalistadmitsconsultordered  :  98.73333333333333
# antibioticsadministerediv  :  89.71666666666667

# %%
mask_admission =df_pat['Type'] == 'Order - Admission'
mask_disch = df_pat['Type'] == 'Order - Discharge'

# %%
admi_time = df_pat.iloc[np.where(mask_disch)[0][0]]['Calculated_DateTime']
admi_time
# Out:
# Timestamp('2023-10-12 22:18:00')

# %%
df_pat[mask_disch]['Calculated_DateTime']
# Out:
# 13506915   2023-10-12 22:18:00
# Name: Calculated_DateTime, dtype: datetime64[ns]

# %%
df_pat[df_pat['EVENT_NAME_NORM']=='hospitalistadmitsconsultcalled']['Calculated_DateTime']
# Out:
# 9130538   2023-10-12 18:09:15
# Name: Calculated_DateTime, dtype: datetime64[ns]

# %%
df_pat['Type'].value_counts()
# Out:
# Event                 121
# Lab Order - Result     70
# Order - Lab            33
# Order - Nursing        27
# Order - Medication     23
# Order - Imaging        13
# Order - Consult         2
# Order - Discharge       1
# Name: Type, dtype: int64

# %%
(df_pat[df_pat['Type'] == 'Order - Discharge']['Calculated_DateTime'].iloc[0]-df_pat[df_pat['EVENT_NAME_NORM']=='hospitalistadmitsconsultcalled']['Calculated_DateTime'].iloc[0]).total_seconds()/60
# Out:
# 248.75

# %% [markdown]
# # HOw many Type='Order - Admission', Type='Order - Discharge' per subject.
# # How many different EVENT_NAME for each ORDER - Admission and Order - Discharge

# %%
groups = df_all.groupby('PAT_ENC_CSN_ID')
admi_dis_dict = {}
for g, df_g in groups:
    admi_mask = df_g['Type']=='Order - Admission'
    dish_mask = df_g['Type']=='Order - Discharge'
    admi_dis_dict[g] = (admi_mask.sum(), dish_mask.sum())

# %%
admi_orders = list(map(lambda x: x[1][0], admi_dis_dict.items()))

# %%
np.min(admi_orders), np.median(admi_orders), np.mean(admi_orders), np.max(admi_orders)
# Out:
# (0, 0.0, 0.7807883821260635, 10)

# %%
admi_orders_10 = list(filter(lambda x: x[1][0]==10, admi_dis_dict.items()))

# %%
len(admi_orders_1)
# Out:
# 15915

# %%
len(admi_orders_2)
# Out:
# 23979

# %%
len(admi_orders_3)
# Out:
# 4789

# %%
len(admi_orders_5)
# Out:
# 262

# %%
len(admi_orders_6)
# Out:
# 72

# %%
len(admi_orders_7)
# Out:
# 20

# %%
len(admi_orders_8)
# Out:
# 7

# %%
len(admi_orders_9)
# Out:
# 6

# %%
len(admi_orders_10), admi_orders_10
# Out:
# (1, [(685379149, (10, 0))])

# %%
df_all[(df_all['PAT_ENC_CSN_ID']==685379149)&(df_all['Type']=='Order - Admission')][['Calculated_DateTime', 'EVENT_NAME', 'Order_Status']]
# Out:
#         Calculated_DateTime                                  EVENT_NAME  \
# 5509324 2023-07-17 05:24:00  POTENTIAL ADMISSION BED BOARD NOTIFICATION
# 5509325 2023-07-17 05:29:00  POTENTIAL ADMISSION BED BOARD NOTIFICATION
# 5051725 2023-07-17 08:44:00  POTENTIAL ADMISSION BED BOARD NOTIFICATION
# 6600140 2023-07-17 09:50:00  POTENTIAL ADMISSION BED BOARD NOTIFICATION
# 6314670 2023-07-17 09:50:00  POTENTIAL ADMISSION BED BOARD NOTIFICATION
# 5500204 2023-07-17 13:28:00  POTENTIAL ADMISSION BED BOARD NOTIFICATION
# 6600144 2023-07-17 13:28:00  POTENTIAL ADMISSION BED BOARD NOTIFICATION
# 6600145 2023-07-17 13:29:00  POTENTIAL ADMISSION BED BOARD NOTIFICATION
# 6600793 2023-07-17 13:56:00                        ADMIT AS OBSERVATION
# 5253713 2023-07-17 13:57:00                        ADMIT AS OBSERVATION
#
#         Order_Status
# 5509324     Canceled
# 5509325     Canceled
# 5051725     Canceled
# 6600140     Canceled
# 6314670     Canceled
# 5500204     Canceled
# 6600144    Completed
# 6600145    Completed
# 6600793    Completed
# 5253713    Completed

# %%
df_all[df_all['Type'] == 'Order - Admission']['EVENT_NAME'].value_counts()
# Out:
# POTENTIAL ADMISSION BED BOARD NOTIFICATION    49413
# ADMIT AS INPATIENT                            20061
# ADMIT AS OBSERVATION                          13913
# ADMIT AS OUTPATIENT                            1073
# ADMIT AS OUTPATIENT-IN-A-BED                     58
# Name: EVENT_NAME, dtype: int64

# %%
df_all[df_all['Type'] == 'Order - Discharge']['EVENT_NAME'].value_counts()
# Out:
# DISCHARGE PATIENT            389
# DISCHARGE EXPIRED PATIENT      2
# Name: EVENT_NAME, dtype: int64
