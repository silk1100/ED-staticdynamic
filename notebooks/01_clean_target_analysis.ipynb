# %%
import pandas as pd
import json
import os
import numpy as np
import random
from collections import defaultdict, Counter
import seaborn as sns

# %%
RAW_DATA_PATH = '/work/InternalMedicine/s223850/raw_data/ED Events - 11.21.23.csv'
CLEAN_DATA_DIR = '/work/InternalMedicine/s223850/ED-StaticDynamic/clean_target'
clean_date_folder = "12_1_23"

# %%
df_raw = pd.read_csv(RAW_DATA_PATH)
df_raw['Calculated_DateTime'] = pd.to_datetime(df_raw['Calculated_DateTime'])
df_raw['Arrived_Time'] = pd.to_datetime(df_raw['Arrived_Time'])

# %%
df_clean =  pd.read_csv(os.path.join(CLEAN_DATA_DIR, clean_date_folder, 'df_clean.csv'))
df_clean['Calculated_DateTime'] = pd.to_datetime(df_clean['Calculated_DateTime'])
df_clean['Arrived_Time'] = pd.to_datetime(df_clean['Arrived_Time'])

# %%
with open(os.path.join(CLEAN_DATA_DIR, clean_date_folder, 'error_pat.json'), 'r') as f:
    errors_pat_list = json.load(f)

len(errors_pat_list)
# Out:
# 10209

# %%
with open(os.path.join(CLEAN_DATA_DIR, clean_date_folder, 'orderbflag.json'), 'r') as f:
    orderbflag_list = json.load(f)
len(orderbflag_list)
# Out:
# 1135

# %%
random_error_pat_id = random.choice(errors_pat_list)

# %%
df_sample = df_raw[df_raw['PAT_ENC_CSN_ID']==random_error_pat_id].sort_values(by='Calculated_DateTime')[['PAT_MRN_ID', 'PAT_ENC_CSN_ID', 'Arrived_Time', 'Calculated_DateTime', 'Type', 'EVENT_NAME']]
df_sample
# Out:
#           PAT_MRN_ID  PAT_ENC_CSN_ID        Arrived_Time Calculated_DateTime  \
# 14131605    97335200       686478795 2023-08-03 23:42:00 2023-08-03 23:42:16
# 14131606    97335200       686478795 2023-08-03 23:42:00 2023-08-03 23:42:29
# 14131607    97335200       686478795 2023-08-03 23:42:00 2023-08-03 23:42:29
# 14131608    97335200       686478795 2023-08-03 23:42:00 2023-08-03 23:42:29
# 14131609    97335200       686478795 2023-08-03 23:42:00 2023-08-03 23:42:29
# 14131610    97335200       686478795 2023-08-03 23:42:00 2023-08-03 23:44:33
# 14131611    97335200       686478795 2023-08-03 23:42:00 2023-08-03 23:49:17
# 14131612    97335200       686478795 2023-08-03 23:42:00 2023-08-04 00:01:00
# 14131613    97335200       686478795 2023-08-03 23:42:00 2023-08-04 00:02:28
# 14131614    97335200       686478795 2023-08-03 23:42:00 2023-08-04 00:02:28
# 14131615    97335200       686478795 2023-08-03 23:42:00 2023-08-04 00:05:04
#
#                      Type                        EVENT_NAME
# 14131605            Event       Emergency encounter created
# 14131606            Event      Admission Med List Generated
# 14131607            Event      Admission FAM List Generated
# 14131608            Event             Patient arrived in ED
# 14131609            Event      Prev Admission Rec Generated
# 14131610            Event               ED SECONDARY TRIAGE
# 14131611            Event                  Triage Completed
# 14131612  Order - Imaging  XR KNEE RIGHT COMPLETE W/PATELLA
# 14131613            Event                    RME Note Filed
# 14131614            Event                         ED Census
# 14131615            Event              Registration Started

# %%
df_sample['EVENT_NAME'].value_counts()
# Out:
# US DOPPLER VENOUS DVT LOWER EXTREMITY BILATERAL           2
# Patient Moving                                            2
# Emergency encounter created                               1
# Patient arrived in ED                                     1
# Admission FAM List Generated                              1
# Prev Admission Rec Generated                              1
# Admission Med List Generated                              1
# Triage Started                                            1
# ED SECONDARY TRIAGE                                       1
# Triage Completed                                          1
# MATH (PE DC) Research Study Page                          1
# Patient roomed in ED                                      1
# Patient transferred                                       1
# ED Ret to WR                                              1
# ED Course - Free Text                                     1
# LWBS Documented -Patient is not responding when called    1
# Name: EVENT_NAME, dtype: int64

# %%
incomplete = [685745685, 676224350, 651612649, 651577643, 651643314]
pregnant_attrs = [663583112]

# %%
small_df = []
for l in errors_pat_list:
    df_sample = df_raw[df_raw['PAT_ENC_CSN_ID']==l]
    if len(df_sample) <=10:
        small_df.append(l)

# %%
len(small_df)/len(errors_pat_list)
# Out:
# 0.5520370918417677

# %%
df_raw[df_raw['PAT_ENC_CSN_ID'] == small_df[9]][['PAT_ENC_CSN_ID','EVENT_NAME']]
# Out:
#        PAT_ENC_CSN_ID                   EVENT_NAME
# 30280       651643314  Emergency encounter created

# %%
df_clean.groupby('PAT_ENC_CSN_ID', group_keys=False)['Admitted_YN'].apply(lambda x: x.iloc[-1]=='Admitted').sum()
# Out:
# 44130

# %%
df_clean.groupby('PAT_ENC_CSN_ID', group_keys=False)['Admitted_YN'].apply(lambda x: x.iloc[-1]=='Not Admitted').sum()
# Out:
# 66563

# %%
44130/110693
# Out:
# 0.39867019594734987

# %%
44130+66563
# Out:
# 110693

# %% [markdown]
# # If I am filtering out "short" encounters. What threshold should be used?
#
# **Assumptions** <br>
# 1. Short encounter is somewhat less that 10 events

# %%
df_clean = df_clean.sort_values(by='Calculated_DateTime')

# %%
groups = df_clean.groupby('PAT_ENC_CSN_ID')

# %%
events_cnt = defaultdict(list)
for pat_id, df_grb in groups:
    for i in range(200):
        if i<len(df_grb):
            events_cnt[i].append(df_grb.iloc[i]['EVENT_NAME'])

# %%
Counter(events_cnt[6]).most_common()
# Out:
# [('Triage Completed', 30162),
#  ('ED SECONDARY TRIAGE', 16300),
#  ('Patient Moving', 6871),
#  ('Patient roomed in ED', 6589),
#  ('Bed was Held', 3980),
#  ('Initial ED Provider Contact', 3250),
#  ('BLOOD GLUCOSE POCT', 3026),
#  ('POSS Documented', 2917),
#  ('IP NUR BLOOD SUGAR BELOW 70', 2441),
#  ('Swallow Screen Trigger Event', 2189),
#  ('TRIAGE DIRECT TO ROOM', 2160),
#  ('RN Re-Assement Note Filed', 2101),
#  ('GLUCOSE POC METER', 2074),
#  ('CBC WITH DIFFERENTIAL', 2021),
#  ('CBC W/ DIFF', 1806),
#  ('URINALYSIS + REFLEX MICROSCOPIC', 1573),
#  ('Triage Started', 1445),
#  ('CMPL (COMPREHENSIVE METABOLIC PANEL)', 1319),
#  ('RME Note Filed', 1101),
#  ('TROPONIN I HS', 1048),
#  ('IP NUR PHYSICIAN COMMUNICATION TO NURSING', 739),
#  ('IP NUR INSERT PERIPHERAL IV', 715),
#  ('IP NUR NOTIFY PHYSICIAN (SPECIFY)', 707),
#  ('SODIUM CHLORIDE 0.9 % SYRINGE', 700),
#  ('IP NUR IN AND OUT CATHETERIZATION', 673),
#  ('CORONAVIRUS, COVID-19 W/ OR W/O RESPIRATORY TESTING', 627),
#  ('BMP (BASIC METABOLIC PANEL)', 584),
#  ('XR CHEST 1 VIEW', 522),
#  ('LACTATE (LACTIC ACID) SERUM', 501),
#  ('LIPASE SERUM', 496),
#  ('IP NUR UR PREG POCT', 494),
#  ('BNP', 412),
#  ('XR CHEST 2 VIEWS', 341),
#  ('CT BRAIN WO IV CONTRAST', 320),
#  ('Patient arrived in ED', 316),
#  ('Prev Admission Rec Generated', 309),
#  ('Admission FAM List Generated', 265),
#  ('Admission Med List Generated', 254),
#  ('IP NUR INITIATE SUICIDE PRECAUTION', 241),
#  ('IP NUR INITIATE SITTER', 233),
#  ('CARDIAC MONITORING (ICU)', 167),
#  ('HEPATIC FUNCTION PANEL', 152),
#  ('Registration Started', 148),
#  ('IP NUR MEASURE BLOOD PRESSURE', 141),
#  ('FLUID BOLUS', 140),
#  ('CT ABDOMEN/PELVIS W IV CONTRAST', 137),
#  ('C REACTIVE PROTEIN (INFLAMMATION MARKER)', 129),
#  ('PROTHROMBIN TIME + INR', 129),
#  ('IP NUR CONTINUOUS PULSE OXIMETRY', 111),
#  ('ACETAMINOPHEN 500 MG TAB', 102),
#  ('TYPE AND SCREEN', 98),
#  ('DRUG SCREEN URINE', 96),
#  ('ACETAMINOPHEN 325 MG TAB', 87),
#  ('PTT (APTT)', 85),
#  ('UTSW CODE SEPSIS PAGE', 84),
#  ('CT CERVICAL SPINE WO IV CONTRAST', 84),
#  ('ED Census', 83),
#  ('TSH REFLEX', 81),
#  ('IP NUR VITAL SIGNS', 79),
#  ('ONDANSETRON HCL (PF) 4 MG/2 ML INJECTION', 74),
#  ('IP NUR VISUAL ACUITY SCREENING', 68),
#  ('LDH SERUM', 65),
#  ('PHOSPHORUS SERUM', 63),
#  ('IP NUR BMP ISTAT', 58),
#  ('IBUPROFEN 400 MG TAB', 56),
#  ('XR FOOT RIGHT AP LATERAL AND OBLIQUE', 55),
#  ('IP NUR MEASURE WEIGHT', 55),
#  ('Assign Nurse', 53),
#  ('XR HAND LEFT PA LATERAL AND OBLIQUE', 53),
#  ('MAGNESIUM LEVEL SERUM', 53),
#  ('Assign Attending', 52),
#  ('FERRITIN', 51),
#  ('IP NUR STRICT INTAKE/OUTPUT', 50),
#  ('US DOPPLER VENOUS DVT LOWER EXTREMITY LEFT', 49),
#  ('File Assign Attending and First Provider Contact', 48),
#  ('GLUCOSE POC', 48),
#  ('IP NUR NURSING OXYGEN ORDERS/INSTRUCTIONS', 45),
#  ('Lab Ordered', 44),
#  ('XR FOOT LEFT AP LATERAL AND OBLIQUE', 43),
#  ('Freq Patient', 42),
#  ('KETOROLAC TROMETHAMINE 15 MG/ML INJECTION', 42),
#  ('IP NUR INSERT IV SALINE LOCK', 41),
#  ('ED Ret to WR', 40),
#  ('XR ANKLE LEFT AP LATERAL AND OBLIQUE', 38),
#  ('ESR (FOR SLE MONITORING)', 38),
#  ('ABO RECHECK', 38),
#  ('XR HAND RIGHT PA LATERAL AND OBLIQUE', 36),
#  ('CT LUMBAR SPINE WO IV CONTRAST', 35),
#  ('LIDOCAINE 5 % (700 MG/PATCH) ADHESIVE PATCH', 35),
#  ('BETA HCG', 35),
#  ('IP NUR VBG', 35),
#  ('XR ANKLE RIGHT AP LATERAL AND OBLIQUE', 32),
#  ('US DOPPLER VENOUS DVT LOWER EXTREMITY RIGHT', 32),
#  ('LWBS Documented -Patient is not responding when called', 31),
#  ('C. TRACH AND N. GONORRHOEAE PCR, URINE', 31),
#  ('XR SHOULDER RIGHT 2 VIEWS', 31),
#  ('Expected arrival', 30),
#  ('RETICULOCYTE PANEL', 30),
#  ('HYDROCODONE-ACETAMINOPHEN 5 MG-325 MG TAB', 29),
#  ('XR HIP RIGHT AP AND LATERAL', 27),
#  ('Pt rounding timer started', 27),
#  ('ONDANSETRON 4 MG TAB, RAPID DISSOLVE', 27),
#  ('XR SHOULDER LEFT 2 VIEWS', 27),
#  ('CT MAXILLOFACIAL WO IV CONTRAST', 26),
#  ('IP NUR BLADDER SCAN', 26),
#  ('XR HIP LEFT AP AND LATERAL', 26),
#  ('XR KNEE RIGHT AP AND LATERAL', 25),
#  ('XR TIBIA FIBULA RIGHT 2 VIEWS', 25),
#  ('XR KNEE LEFT AP AND LATERAL', 24),
#  ('XR LUMBAR SPINE 2-3 VIEWS', 24),
#  ('Blood Product Ready', 24),
#  ('US DOPPLER VENOUS DVT LOWER EXTREMITY BILATERAL', 23),
#  ('IP NUR BEDSIDE DYSPHAGIA SCREEN', 22),
#  ('IP NUR NEURO VITAL SIGNS', 22),
#  ('XR TIBIA FIBULA LEFT 2 VIEWS', 21),
#  ('DIPHENHYDRAMINE 25 MG CAP', 20),
#  ('CORONAVIRUS, COVID-19 RAPID (ID NOW)', 20),
#  ('TETANUS AND DIPHTHERIA TOX (PF) 5 LF UNIT-2 LF UNIT/0.5 ML IM SYRINGE', 20),
#  ('CT MAXILLOFACIAL W IV CONTRAST', 20),
#  ('IP NUR NEURO CHECKS', 19),
#  ('METHOCARBAMOL 750 MG TAB', 19),
#  ('CT RENAL COLIC WO IV CONTRAST', 19),
#  ('Private Manage Orders Pend', 19),
#  ('Pt rounding completed', 18),
#  ('CT NECK SOFT TISSUE W IV CONTRAST', 18),
#  ('XR WRIST LEFT 3 VIEW', 18),
#  ('MAGNESIUM SERUM', 18),
#  ('HEPARIN ASSAY (LMWH)', 17),
#  ('DIPHTH,PERTUS(ACEL),TETANUS VAC-PF 2 LF-(5-3-5MCG)-5 LF/0.5 ML IM SUSP',
#   17),
#  ('METHOCARBAMOL 500 MG TAB', 17),
#  ('XR KNEE LEFT COMPLETE W/PATELLA', 17),
#  ('XR KNEE RIGHT COMPLETE W/PATELLA', 16),
#  ('MATH (PE DC) Research Study Page', 16),
#  ('AMMONIA', 16),
#  ('XR ELBOW RIGHT AP LATERAL AND OBLIQUE', 16),
#  ('US PELVIS', 15),
#  ('XR WRIST RIGHT 3 VIEW', 15),
#  ('US DOPPLER VENOUS DVT UPPER EXTREMITY RIGHT', 15),
#  ('DIPHTH, PERTUS(ACELL), TETANUS 2.5 LF UNIT-8 MCG-5 LF/0.5 ML IM SUSP', 15),
#  ('US ABDOMEN LIMITED (RUQ)', 14),
#  ('MORPHINE 4 MG/ML INTRAVENOUS SYRINGE', 14),
#  ('PREDNISONE 20 MG TAB', 14),
#  ('D-DIMER', 14),
#  ('SODIUM CHLORIDE 0.9 % IV', 13),
#  ('XR FEMUR RIGHT MIN 2 VIEWS', 13),
#  ('US UTERUS PREGNANT <14 WEEKS W TRANSVAGINAL', 13),
#  ('ALCOHOL ETHYL SERUM', 13),
#  ('XR KNEE LEFT AP LATERAL AND OBLIQUE', 12),
#  ('XR FOREARM RIGHT AP AND LATERAL', 12),
#  ('ESR (CRP IS GENERALLY SUPERIOR)', 12),
#  ('ED Note Pended', 11),
#  ('PROCHLORPERAZINE EDISYLATE 10 MG/2 ML (5 MG/ML) INJECTION', 11),
#  ('SALICYLATE', 11),
#  ('XR FOREARM LEFT AP AND LATERAL', 10),
#  ('PHARMACY CONSULT FOR INTRATHECAL PUMP MEDICATION ORDER', 10),
#  ('XR FEMUR LEFT MIN 2 VIEWS', 10),
#  ('ED EFI Start', 10),
#  ('Trauma Start', 10),
#  ('CT THORACIC SPINE WO IV CONTRAST', 9),
#  ('XR PELVIS 1-2 VIEWS', 9),
#  ('XR KNEE RIGHT AP LATERAL AND OBLIQUE', 9),
#  ('IP NURSE FULL NIHSS SCALE', 9),
#  ('Waiting for Provider', 9),
#  ('XR ELBOW LEFT AP LATERAL AND OBLIQUE', 9),
#  ('HCG QUAL SERUM', 9),
#  ('FLUORESCEIN 1 MG EYE STRIPS', 9),
#  ('CT ABDOMEN/PELVIS WO IV CONTRAST', 9),
#  ('MR BRAIN/BRAIN STEM W AND WO CONTRAST', 9),
#  ('FAMOTIDINE 20 MG TAB', 8),
#  ('ASPIRIN 81 MG CHEWABLE TAB', 8),
#  ('XR THORACIC SPINE AP AND LATERAL 2 VIEWS', 8),
#  ('XR FINGERS LEFT 2 VIEWS', 8),
#  ('CK (CPK)', 8),
#  ('COVID + RESPIRATORY PCR PANEL TESTING', 8),
#  ('XR HUMERUS RIGHT AP AND LATERAL', 8),
#  ('US RENAL COMPLETE', 8),
#  ('SODIUM CHLORIDE 0.9 % PRESERVATIVE FREE INJECTION', 8),
#  ('Remove Nurse', 8),
#  ('XR RIBS RIGHT W/CHEST MIN 3 VIEWS', 8),
#  ('N TERMINAL PROBNP', 8),
#  ('CT ANGIOGRAPHY CHEST PULMONARY ARTERIES WO/ W IV CONTRAST', 8),
#  ('IBUPROFEN 600 MG TAB', 7),
#  ('Re-assessment timer reset', 7),
#  ('US GALLBLADDER', 7),
#  ('Re-assessment completed', 7),
#  ('IP NUR PATIENT CARE ORDER (SPECIFY)', 7),
#  ('HIV- 1 + 2 AG /AB SCREENING ASSAY', 7),
#  ('US SCROTUM (TESTICLES)', 7),
#  ('FAMOTIDINE (PF) 20 MG/2 ML IV', 7),
#  ('BALANCED SALT IRRIG SOLN COMB2 INTRAOCULAR (15 ML)- SURGERY', 7),
#  ('HYDROMORPHONE 0.5 MG/0.5 ML INJECTION SYRINGE', 7),
#  ('XR RIBS LEFT W/CHEST MIN 3 VIEWS', 7),
#  ('CT ANGIOGRAM BRAIN AND NECK W AND/OR WO IV CONTRAST', 7),
#  ('TSH', 7),
#  ('IPRATROPIUM-ALBUTEROL 0.5 MG-2.5 MG/3 ML NEB SOLUTION', 7),
#  ('EFI Return to ED Status', 7),
#  ('IP NEU CT NOTIFICATION STROKE PROTOCOL', 7),
#  ('XR SHUNT SERIES', 7),
#  ('TETRACAINE HCL (PF) 0.5 % EYE DROPS', 7),
#  ('MR BRAIN WO CONTRAST', 7),
#  ('XR SHOULDER LEFT INTERNAL EXTERNAL AND AXILLARY', 7),
#  ('PANTOPRAZOLE 40 MG TAB, DELAYED RELEASE', 6),
#  ('US DOPPLER VENOUS DVT UPPER EXTREMITY LEFT', 6),
#  ('IP PC CONSULT TO UROLOGY', 6),
#  ('PANTOPRAZOLE 40 MG IV SOLUTION', 6),
#  ('IP NUR ENCOURAGE FLUIDS', 6),
#  ('IP NUR CARDIAC OUTPUT MONITORING', 6),
#  ('IPRATROPIUM BROMIDE 0.02 % SOLN FOR INHALATION', 6),
#  ('XR ABDOMEN 1 VIEW', 6),
#  ('XR HUMERUS LEFT AP AND LATERAL', 6),
#  ('DIPHENHYDRAMINE 50 MG/ML INJECTION', 6),
#  ('Stroke Documentation Start', 6),
#  ('KETOROLAC TROMETHAMINE 30 MG/ML INJECTION', 6),
#  ('XR SHOULDER RIGHT INTERNAL EXTERNAL AND AXILLARY', 6),
#  ('ALBUTEROL SULFATE 2.5 MG/3 ML (0.083 %) NEB SOLUTION', 6),
#  ('Patient transferred', 5),
#  ('ABO + RH', 5),
#  ('Send Patient to L&D', 5),
#  ('XR HIPS BILATERAL AND AP PELVIS', 5),
#  ('PIPERACILLIN-TAZOBACTAM 4.5G IVPB (MINIBAG PLUS)', 5),
#  ('XR NECK SOFT TISSUE', 5),
#  ('IP NUR APPLY CERVICAL COLLAR', 5),
#  ('ACETAMINOPHEN LEVEL', 5),
#  ('URIC ACID SERUM', 5),
#  ('CT PELVIS BONY WO IV CONTRAST', 5),
#  ('US UTERUS PREGNANT >14 WEEKS', 5),
#  ('MR LUMBAR SPINE W AND WO IV CONTRAST', 5),
#  ('XR FOOT RIGHT AP AND LATERAL', 5),
#  ('GI COCKTAIL ORAL SOLUTION', 5),
#  ('MR LUMBAR SPINE WO IV CONTRAST', 5),
#  ('PROPARACAINE 0.5 % EYE DROPS', 5),
#  ('LACTATED RINGERS IV FOR BOLUS', 5),
#  ('Team Member Assigned', 5),
#  ('CORONAVIRUS, COVID-19 PCR', 4),
#  ('IP NUR IV ACCESS MEDIPORT', 4),
#  ('XR FINGER 1ST DIGIT LEFT', 4),
#  ('DEXTROSE 5% IN WATER (D5W) IV', 4),
#  ('RABIES VACCINE, PURIFIED CHICKEN EMBRYO CELL (PF) 2.5 UNIT IM KIT', 4),
#  ('IP NUR INITIATE ELOPEMENT PRECAUTION', 4),
#  ('XR ANKLE RIGHT AP AND LATERAL', 4),
#  ('KETOROLAC TROMETHAMINE 60 MG/2 ML IM', 4),
#  ('AMLODIPINE 10 MG TAB', 4),
#  ('XR ABDOMEN ACUTE SERIES', 4),
#  ('FLUORESCEIN 0.6 MG EYE STRIPS', 4),
#  ('AMLODIPINE 5 MG TAB', 4),
#  ('XR FINGER RIGHT 1 VIEW', 4),
#  ('XR FINGERS RIGHT 2 VIEWS', 4),
#  ('CT CHEST W IV CONTRAST', 4),
#  ('MR BRAIN LIMITED WO IV CONTRAST', 4),
#  ('XR ANKLE LEFT AP AND LATERAL', 4),
#  ('XR FINGER LEFT 1 VIEW', 4),
#  ('IP PC CONSULT TO NEUROLOGY', 4),
#  ('CONSULT UNIT BASED SOCIAL WORKER FOR SUICIDE ASSESSMENT', 4),
#  ('Taking Flag Changed', 4),
#  ('SYPHILIS SCREENING/DIAGNOSTIC EVALUATION', 3),
#  ('Inpatient Procedure Duplicate', 3),
#  ('MR ORBITS W WO IV CONTRAST', 3),
#  ('Remove Attending', 3),
#  ('ED Lactate Resulted', 3),
#  ('ALBUTEROL SULFATE HFA 90 MCG/ACTUATION AEROSOL INHALER', 3),
#  ('US UTERUS PREGNANT <14 WEEKS ONLY', 3),
#  ('METOCLOPRAMIDE 5 MG/ML INJECTION', 3),
#  ('XR SACRUM AND COCCYX', 3),
#  ('GABAPENTIN 100 MG CAP', 3),
#  ('BILIRUBIN DIRECT SERUM', 3),
#  ('PANTOPRAZOLE 40 MG IN NS 100 ML (MINIBAG PLUS)', 3),
#  ('CLONIDINE 0.1 MG TAB', 3),
#  ('XR CERVICAL SPINE 2 OR 3 VIEWS', 3),
#  ('IP NUR INSERT AND MAINTAIN SALINE LOCK', 3),
#  ('IP NUR MEASURE POST VOID RESIDUAL', 3),
#  ('XR MANDIBLE MIN 4 VIEWS', 3),
#  ('IP PC CONSULT TO PLASTIC SURGERY', 3),
#  ('METHYLPREDNISOLONE SOD SUCC (PF) 125 MG/2 ML SOLUTION FOR INJECTION', 3),
#  ('ED Course - Free Text', 3),
#  ('US NECK OR HEAD SOFT TISSUES', 3),
#  ('AZITHROMYCIN 500 MG IVPB (VIAL2BAG)', 3),
#  ('US BREAST RIGHT - IP ONLY', 3),
#  ('XR SHOULDER RIGHT 1 VIEW', 3),
#  ('XR CLAVICLE LEFT', 3),
#  ('IP NUR ORTHOSTATIC BLOOD PRESSURE', 3),
#  ('IP NUR APPLY ICE TO AFFECTED AREA', 3),
#  ('POTASSIUM URINE RANDOM', 3),
#  ('CEFTRIAXONE 1 G IV PUSH', 2),
#  ('HYDROCODONE-ACETAMINOPHEN 10 MG-325 MG TAB', 2),
#  ('INFLUENZA A+B', 2),
#  ('IP PC CONSULT TO OTOLARYNGOLOGY', 2),
#  ('MISCELLANEOUS MEDICINE', 2),
#  ('LISINOPRIL 20 MG TAB', 2),
#  ('METFORMIN 500 MG TAB', 2),
#  ('ASPIRIN 325 MG TAB, DELAYED RELEASE', 2),
#  ('OMEPRAZOLE 20 MG CAP, DELAYED RELEASE', 2),
#  ('XR RIBS RIGHT 2 VIEWS', 2),
#  ('METHYLPREDNISOLONE SOD SUCC (PF) 40 MG/ML SOLUTION FOR INJECTION', 2),
#  ('LOSARTAN 50 MG TAB', 2),
#  ('LOSARTAN 100 MG TAB', 2),
#  ('IP NUR ACTIVATE CODE STROKE', 2),
#  ('IP PC CONSULT TO NEUROLOGY STROKE CLINIC', 2),
#  ('US LIVER', 2),
#  ('HYDROCHLOROTHIAZIDE 12.5 MG TAB', 2),
#  ('DEXAMETHASONE 4 MG/ML INJECTION', 2),
#  ('IP NUR APPLY HEAT TO AFFECTED AREA', 2),
#  ('OMEPRAZOLE 40 MG CAP, DELAYED RELEASE', 2),
#  ('CETIRIZINE 10 MG TAB', 2),
#  ('US LOWER EXTREMITY SOFT TISSUE LEFT', 2),
#  ('LORAZEPAM 2 MG/ML INJECTION', 2),
#  ('DEXAMETHASONE 4 MG TAB', 2),
#  ('US DOPPLER HEMODIALYSIS GRAFT OR FISTULA', 2),
#  ('BETA-HYDROXYBUTYRIC ACID', 2),
#  ('ED Note Filed', 2),
#  ('AMOXICILLIN-POT CLAVULANATE 875 MG-125 MG TAB', 2),
#  ('HEPATITIS B SURFACE AG', 2),
#  ('IP PC CONSULT TO GYNECOLOGY', 2),
#  ('XR GASTROSTOMY TUBE CHECK', 2),
#  ('CEFTRIAXONE 2 G IV PUSH', 2),
#  ('LIDOCAINE 2 % VISCOUS SOLN', 2),
#  ('US CHEST CAVITY', 2),
#  ('IP NUR LACTATE SERUM ISTAT', 2),
#  ('TIBC + FE', 2),
#  ('ENTERIC VIRUSES PCR', 2),
#  ('RT Lab Ordered', 2),
#  ('XR FINGER 1ST DIGIT RIGHT', 2),
#  ('ACETAMINOPHEN 325 MG/10.15 ML ORAL SUSPENSION', 2),
#  ('MR CERVICAL SPINE W AND WO IV CONTRAST', 2),
#  ('CT ORBITS W IV CONTRAST', 2),
#  ('ALLOPURINOL 100 MG TAB', 2),
#  ('CT ANGIOGRAM AORTA ENTIRE W AND/OR WO IV CONTRAST', 2),
#  ('CT ORBITS WO IV CONTRAST', 2),
#  ('US ANKLE BRACHIAL ARTERIAL INDICES (ABI)', 2),
#  ('IP NUR INITIATE TRANSFUSION REACTION WORKUP', 2),
#  ('MR CERVICAL SPINE WO IV CONTRAST', 2),
#  ('DIAZEPAM 5 MG TAB', 2),
#  ('UTSW IMS TEMPLATE', 2),
#  ('XR ABDOMEN 2 VIEWS', 2),
#  ('POTASSIUM CHLORIDE SR 20 MEQ TAB, PARTICLES/CRYSTALS', 2),
#  ('XR WRIST LEFT 2 VIEWS', 2),
#  ('CALCIUM IONIZED', 2),
#  ('IOHEXOL 9 MG IODINE/ML ORAL SOLUTION', 2),
#  ('CT ANGIOGRAM ABD PEL AND LWR EXT (RUNOFF) W AND/OR WO IV CONT', 2),
#  ('CT BRAIN PERFUSION W IV CONTRAST', 2),
#  ('XR ESOPHAGRAM', 2),
#  ('METHYLPREDNISOLONE 125 MG INJECTION MIXTURE', 2),
#  ('FAMOTIDINE 40 MG TAB', 1),
#  ('ondansetron (ZOFRAN) 4 mg/2 mL injection DOSE:', 1),
#  ('Pain Medication Administration', 1),
#  ('MCH', 1),
#  ('LEVETIRACETAM 500 MG TAB', 1),
#  ('TERBINAFINE 250 MG TAB', 1),
#  ('RSV', 1),
#  ('AMLODIPINE 2.5 MG TAB', 1),
#  ('DIPHENHYDRAMINE 25 MG TAB', 1),
#  ('DOXYCYCLINE HYCLATE 100 MG CAP', 1),
#  ('NONOXYNOL-9 12.5 % VAGINAL FOAM', 1),
#  ('DOCUSATE SODIUM 100 MG CAP', 1),
#  ('ROSUVASTATIN 20 MG TAB', 1),
#  ('SERTRALINE 100 MG TAB', 1),
#  ('BUPROPION XL 150 MG 24 HR TAB', 1),
#  ('FERROUS SULFATE 325 MG (65 MG IRON) TAB', 1),
#  ('NAPROXEN 250 MG TAB', 1),
#  ('CEFTRIAXONE 1 G IV (VIAL2BAG)', 1),
#  ('INSULIN 100 UNIT IN 100 ML NS PREMIX', 1),
#  ('GUAIFENESIN 100 MG/5 ML ORAL LIQUID', 1),
#  ('METFORMIN 1,000 MG TAB', 1),
#  ('NORTRIPTYLINE 10 MG/5 ML ORAL SOLN', 1),
#  ('PROPRANOLOL 20 MG TAB', 1),
#  ('BLOOD PRESSURE CHECK', 1),
#  ('NIFEDIPINE ER 90 MG TAB', 1),
#  ('ALBUTEROL SULF 90 MCG/ACTUATION BREATH ACTIVATED POWDER INHALER,SENSOR', 1),
#  ('CETIRIZINE 1 MG/ML ORAL SOLN', 1),
#  ('FLOVENT HFA 110 MCG/ACTUATION AEROSOL INHALER', 1),
#  ('AZELASTINE 205.5 MCG (0.15 %) NASAL SPRAY', 1),
#  ('IP NUR WOUND IRRIGATION', 1),
#  ('Stroke Neurologist Called', 1),
#  ('HAPTOGLOBIN', 1),
#  ('LIDOCAINE (PF) 1 % INJECTION', 1),
#  ('Code Start', 1),
#  ('METOPROLOL SUCCINATE (TOPROL XL) SR 24-HR 25 MG TAB', 1),
#  ('BUSPIRONE 15 MG TAB', 1),
#  ('IP INITIATE SKIN PATHWAY', 1),
#  ('FUROSEMIDE 10 MG/ML INJECTION', 1),
#  ('OXCARBAZEPINE 300 MG TAB', 1),
#  ('QUETIAPINE 100 MG TAB', 1),
#  ('XR SHOULDER LEFT 1 VIEW', 1),
#  ('T4 FREE', 1),
#  ('ACETAMINOPHEN 100 MG/ML ORAL DROPS', 1),
#  ('XR CLAVICLE RIGHT', 1),
#  ('BUPRENORPHINE-NALOXONE 2 MG-0.5 MG SUBLINGUAL TAB', 1),
#  ('METOPROLOL TARTRATE (LOPRESSOR) 25 MG TAB', 1),
#  ('LEVOTHYROXINE 100 MCG TAB', 1),
#  ('LISINOPRIL 10 MG TAB', 1),
#  ('VANCOMYCIN IV 1250 MG (VIAL2BAG MIXTURE)', 1),
#  ('GABAPENTIN 600 MG TAB', 1),
#  ('MULTIVITAMINS WITH MINERALS TAB', 1),
#  ('CHLORPHENIRAMINE-HYDROCODONE SR 8 MG-10 MG/5 ML ORAL 12 HR SUSP', 1),
#  ('CLONAZEPAM ORAL', 1),
#  ('LISDEXAMFETAMINE 60 MG CHEWABLE TABLET', 1),
#  ('XR NASAL BONES COMPLETE MIN 3 VIEWS', 1),
#  ('FINASTERIDE 5 MG TAB', 1),
#  ('Epi Admin ReTrigger', 1),
#  ('FLUTICASONE 50 MCG/ACTUATION NASAL SPRAY, SUSP', 1),
#  ('FEROSUL 325 MG (65 MG IRON) TAB', 1),
#  ('HEMOGLOBIN A1C', 1),
#  ('ESCITALOPRAM 10 MG TAB', 1),
#  ('FOLIC ACID 1 MG TAB', 1),
#  ('PRAVASTATIN 40 MG TAB', 1),
#  ('LIDOCAINE 4 %-RACEPINEPHRINE 0.05 %-TETRACAINE 0.5 % TOPICAL GEL', 1),
#  ('XR ELBOW RIGHT AP AND LATERAL', 1),
#  ('LISINOPRIL-HYDROCHLOROTHIAZIDE 20 MG-12.5 MG TAB', 1),
#  ('FOLIVANE-F 125 MG-1 MG-40 MG-3 MG CAPSULE', 1),
#  ('MOMETASONE 50 MCG/ACTUATION NASAL SPRAY', 1),
#  ('ASPIRIN 81 MG CAPSULE', 1),
#  ('ALBUTEROL INHL', 1),
#  ('DESVENLAFAXINE ER 100 MG TABLET,EXTENDED RELEASE 24 HR', 1),
#  ('ETONOGESTREL 68 MG SUBDERMAL IMPLANT', 1),
#  ('LEVETIRACETAM, S', 1),
#  ('XR ELBOW LEFT AP AND LATERAL', 1),
#  ('ADVAIR DISKUS INHL', 1),
#  ('FENTANYL (PF) 50 MCG/ML INJECTION', 1),
#  ('CIPROFLOXACIN 0.3 % EYE DROPS', 1),
#  ('DOXAZOSIN 4 MG TAB', 1),
#  ('Trauma Documentation Start', 1),
#  ('ROSUVASTATIN 5 MG TAB', 1),
#  ('IP PC CONSULT TO OBSTETRICS', 1),
#  ('LORATADINE 10 MG TAB', 1),
#  ('LAMOTRIGINE, S', 1),
#  ('Team Member Removed', 1),
#  ('MULTIVIT-IRON 18 MG-FOLIC ACID 400 MCG-CALCIUM 500 MG-MINERALS TABLET', 1),
#  ('OXYBUTYNIN CHLORIDE SR 15 MG 24 HR TAB', 1),
#  ('CELECOXIB 200 MG CAP', 1),
#  ('PRENATAL VIT-IRON FUMARATE-FA 65 MG-1 MG TAB', 1),
#  ('ZOLPIDEM 5 MG TAB', 1),
#  ('SULFAMETHOXAZOLE-TRIMETHOPRIM 200 MG-40 MG/5 ML ORAL SUSP', 1),
#  ('LABETALOL 5 MG/ML IV', 1),
#  ('PROLACTIN', 1),
#  ('MAGNESIUM SULFATE 2 GRAM/50 ML IV PIGGY BACK', 1),
#  ('Consult Ordered: NEUROLOGY', 1),
#  ('LAMOTRIGINE 100 MG TAB', 1),
#  ('LR BOLUS WEIGHT BASED INFUSION', 1),
#  ('VON WILLEBRAND FACTOR(RECOMB) 1,300 (+/-) UNIT RANGE INTRAVENOUS SOLN', 1),
#  ('CREATININE URINE RANDOM', 1),
#  ('TRAMADOL 50 MG TAB', 1),
#  ('Assign ED Resident', 1),
#  ('CEFTRIAXONE 250 MG SOLUTION FOR INJECTION', 1),
#  ('ED Ready For Obs', 1),
#  ('CEFEPIME (MAXIPIME) 6 GRAM INFUSION', 1),
#  ('ALLOPURINOL 300 MG TAB', 1),
#  ('LOSARTAN-HYDROCHLOROTHIAZIDE 50 MG-12.5 MG TAB', 1),
#  ('Consult Ordered: ENT', 1),
#  ('PAROXETINE 10 MG TAB', 1),
#  ('HLA SERUM STORAGE', 1),
#  ('KETOROLAC TROMETHAMINE 10 MG TAB', 1),
#  ('DULOXETINE 20 MG CAP, DELAYED RELEASE', 1),
#  ('GLIPIZIDE 5 MG TAB', 1),
#  ('ALBUTEROL SULFATE HFA 90 MCG/ACTUATION AEROSOL INHALER FOR PULMONARY', 1),
#  ('PAXLOVID 300 MG (150 MG X 2)-100 MG TABLETS IN A DOSE PACK (EUA)', 1),
#  ('VITAMIN B12', 1),
#  ('PAROXETINE 20 MG TAB', 1),
#  ('APIXABAN 5 MG TABLET', 1),
#  ('LOSARTAN 25 MG TAB', 1),
#  ('BIKTARVY ORAL', 1),
#  ('PRAZOSIN 1 MG CAP', 1),
#  ('IP NUR FLUSH/IRRIGATION', 1),
#  ('OXYMETAZOLINE 0.05 % NASAL SPRAY AEROSOL', 1),
#  ('ED Provider Arrival', 1),
#  ('MID Team Member Assigned', 1),
#  ('HYDROCHLOROTHIAZIDE 25 MG TAB', 1),
#  ('IP NUR LINE READY FOR USE', 1),
#  ('XR CALCANEOUS LEFT AP AND LATERAL', 1),
#  ('TOTAL PROTEIN', 1),
#  ('XR PUMP CHECK', 1),
#  ('ALBUMIN BODY FLUID', 1),
#  ('P53 MUT BLD', 1),
#  ('XR FOOT LEFT AP AND LATERAL', 1),
#  ('LIDOCAINE 1 % INJECTION', 1),
#  ('METRONIDAZOLE IN SODIUM CHLORIDE (ISO-OSM) 500 MG/100 ML IV PIGGY BACK', 1),
#  ('METHEMOGLOBIN AND SULFHEMOGLOBIN, B', 1),
#  ('OCTREOTIDE INFUSION', 1),
#  ('ENTERIC PARASITES PCR', 1),
#  ('YEAST, UA', 1),
#  ('IP NUR 1:1 PATIENT', 1),
#  ('LORazepam (ATIVAN) 2 mg/mL injection DOSE:', 1),
#  ('PREGNANCY TEST URINE', 1),
#  ('IBUPROFEN 100 MG/5 ML ORAL SUSP', 1),
#  ('AMPHETAMINE-DEXTROAMPHETAMINE 10 MG TAB', 1),
#  ('CHOLECALCIFEROL (VITAMIN D3) 10 MCG/DROP (400 UNIT/DROP) ORAL DROPS', 1),
#  ('CEFPODOXIME 200 MG TAB', 1),
#  ('MONONUCLEOSIS SCREEN', 1),
#  ('IP NUR SETUP PELVIC EXAM', 1),
#  ('FIBRINOGEN', 1),
#  ('XR HUMERUS LEFT 1 VIEW', 1),
#  ('ASPIRIN 325 MG TAB', 1),
#  ('IP NUR BNP ISTAT', 1),
#  ('LEVOTHYROXINE 88 MCG TAB', 1),
#  ('GABAPENTIN 400 MG CAP', 1),
#  ('POTASSIUM SERUM', 1),
#  ('Patient Transport In Progress', 1),
#  ('VANCOMYCIN IV 1500 MG (VIAL2BAG MIXTURE)', 1),
#  ('EPINEPHRINE 0.3 MG/0.3 ML (1:1,000) IM PEN INJECTOR', 1),
#  ('IP NUR INSERT FOLEY CATHETER', 1),
#  ('LIDOCAINE 2 % JELLY IN UROJET APPLICATOR', 1),
#  ('ALBUMIN SERUM', 1),
#  ('US DOPPLER LIVER TRANSPLANT', 1),
#  ('ED Course - Vitals', 1),
#  ('OSMOLALITY URINE', 1),
#  ('MG/LE MYASTHENIC SYNDROME EVALUATION, SERUM', 1),
#  ('HYDROXYZINE PAMOATE 25 MG CAP', 1),
#  ('GABAPENTIN 300 MG CAP', 1),
#  ('DICYCLOMINE 10 MG/ML IM', 1),
#  ('CEFUROXIME AXETIL 500 MG TAB', 1),
#  ('ATORVASTATIN 40 MG TAB', 1),
#  ('LISINOPRIL-HYDROCHLOROTHIAZIDE 10 MG-12.5 MG TAB', 1),
#  ('CARBON MONOXIDE, B', 1),
#  ('THERAPEUTIC MULTIVITAMIN TAB', 1),
#  ('US PSEUDOANEURYSM', 1),
#  ('IP NUR WOUND CARE', 1),
#  ('US DOPPLER PENILE', 1),
#  ('BUTALBITAL-ACETAMINOPHEN-CAFFEINE 50 MG-325 MG-40 MG TAB', 1),
#  ('BILIRUBIN TOTAL SERUM', 1),
#  ('IP NEPHROLOGY GENERAL', 1),
#  ('CT LOWER EXTREMITY RIGHT W IV CONTRAST', 1),
#  ('MR ANGIOGRAM BRAIN W AND WO IV CONTRAST', 1),
#  ('METFORMIN 850 MG TAB', 1),
#  ('METOPROLOL SUCCINATE (TOPROL XL) SR 24-HR 50MG TAB', 1),
#  ('IP PC CONSULT TO PSYCHIATRY - CUH ', 1),
#  ('PROCHLORPERAZINE MALEATE 5 MG TAB', 1),
#  ('Consult Ordered: UROLOGY', 1),
#  ('IRON SERUM', 1),
#  ('CHLORIDE URINE RANDOM', 1),
#  ('DROPERIDOL 2.5 MG/ML INJECTION', 1),
#  ('RDW', 1),
#  ('HYDROMORPHONE IVPB INFUSION', 1),
#  ('XR TOE 1ST DIGIT RIGHT MIN 2 VIEWS', 1),
#  ('MR THORACIC SPINE W AND WO IV CONTRAST', 1),
#  ('CORTISOL SERUM', 1),
#  ('SODIUM CHLORIDE 0.9% FOR BOLUS', 1),
#  ('ENTERIC BACTERIA PCR', 1),
#  ('HYDROMORPHONE 1 MG/ML INJECTION', 1),
#  ('IP NUR VERIFY (SPECIFY)', 1),
#  ('CT TEMPORAL BONE/EAR WO IV CONTRAST', 1),
#  ('DEXTROSE 10% IN WATER (D10W) IV SOLN', 1),
#  ('MR BRAIN W AND WO CONTRAST', 1),
#  ('XR PELVIS MINIMUM 3 VIEW', 1),
#  ('HOV Confirmed', 1),
#  ('XR LUMBAR SPINE MIN 4 VIEWS', 1),
#  ('US GROIN', 1),
#  ('Expired - Left ED', 1),
#  ('IP NUR TROPONIN I ISTAT', 1),
#  ('VANCOMYCIN 1 GM IVPB IN NS/D5W (VIAL2BAG)', 1),
#  ('NAPROXEN 500 MG TAB', 1),
#  ('TACROLIMUS (FK506) LEVEL', 1),
#  ('XR RIBS LEFT 2 VIEWS', 1),
#  ('CT CHEST WO IV CONTRAST', 1),
#  ('C. TRACH AND N. GONORRHOEAE PCR, CERVICAL THIN PREP', 1),
#  ('NW PROC GENERAL', 1),
#  ('METHOCARBAMOL 100 MG/ML INJECTION', 1),
#  ('BACITRACIN 500 UNIT/G OINTMENT', 1),
#  ('LORAZEPAM 0.5 MG TAB', 1),
#  ('TRANEXAMIC ACID 1,000 MG/10 ML (100 MG/ML) INTRAVENOUS SOLUTION', 1),
#  ('METHYLPREDNISOLONE 40 MG INJECTION MIXTURE', 1),
#  ('SERTRALINE 50 MG TAB', 1),
#  ('SODIUM CHLORIDE 0.45 % IV', 1),
#  ('CT OUTSIDE STUDY ABDOMEN/PELVIS INTERPRETATION REQUEST', 1),
#  ('IP NUR CIWA-AR ASSESSMENT', 1),
#  ('THIAMINE MONONITRATE (VITAMIN B1) 100 MG TABLET', 1),
#  ('MORPHINE IVPB INFUSION', 1),
#  ('DEXTROSE 5%-LACTATED RINGERS IV', 1),
#  ('IP NUR INSERT AND/OR MAINTAIN FOLEY CATHETER', 1),
#  ('XR TOE 5TH DIGIT RIGHT MIN 2 VIEWS', 1),
#  ('CEFTRIAXONE 500 MG SOLUTION FOR INJECTION', 1),
#  ('IP NUR CALL DOCTOR', 1),
#  ('IP RT SPONTANEOUS PARAMETERS', 1),
#  ('ANASTROZOLE 1 MG TAB', 1),
#  ('CEPHALEXIN 500 MG CAP', 1),
#  ('CT BRAIN W IV CONTRAST', 1)]

# %%
df_len = groups.apply(lambda x: len(x))

# %%
df_len[df_len>=6]
# Out:
# PAT_ENC_CSN_ID
# 86725001      99
# 619927095     10
# 651542751     30
# 651542792     31
# 651542795    110
#             ...
# 693399528     96
# 693399583     83
# 693401044    112
# 693401129     16
# 693401341     33
# Length: 110300, dtype: int64

# %%
110300/len(df_len)
# Out:
# 0.9964496399953023

# %%
set(df_len[df_len>=6].index)
# Out:
# {669253632,
#  680001536,
#  677117954,
#  686555140,
#  670302213,
#  681050118,
#  685768709,
#  691535876,
#  674496522,
#  666894347,
#  669515787,
#  681574410,
#  687341579,
#  685768721,
#  662175762,
#  664797204,
#  662437909,
#  685768728,
#  651690013,
#  665321502,
#  661913631,
#  674496541,
#  681050144,
#  684982307,
#  669253668,
#  681574436,
#  687341610,
#  686817325,
#  687341618,
#  688128051,
#  691798068,
#  662437942,
#  691535927,
#  651690045,
#  687341629,
#  686555201,
#  676069442,
#  665583683,
#  691535940,
#  668467269,
#  674758728,
#  687341640,
#  657981514,
#  673972298,
#  671613004,
#  679215183,
#  664010835,
#  683671635,
#  690487380,
#  672399447,
#  665583704,
#  674496601,
#  684982362,
#  664535136,
#  675020897,
#  686555235,
#  689963109,
#  655097958,
#  690487398,
#  691798119,
#  688334806,
#  664797295,
#  672923762,
#  690487411,
#  691535988,
#  654311541,
#  681574517,
#  662438007,
#  684720246,
#  651952261,
#  659292294,
#  662438029,
#  684982413,
#  667943056,
#  671088786,
#  653787283,
#  653787284,
#  667156627,
#  687341714,
#  657457305,
#  666370202,
#  674496667,
#  685244572,
#  681836701,
#  656933027,
#  665845924,
#  673185960,
#  684196018,
#  687341750,
#  664010936,
#  676331707,
#  655098045,
#  671875261,
#  662438079,
#  684982466,
#  685768899,
#  666108100,
#  654049478,
#  652738763,
#  680526027,
#  670564560,
#  672923857,
#  674496722,
#  684982485,
#  656408792,
#  667418842,
#  668467419,
#  675807450,
#  662438113,
#  682098913,
#  684982502,
#  691798248,
#  655098091,
#  684982507,
#  667418862,
#  657719540,
#  661913846,
#  681574650,
#  651690235,
#  675807483,
#  684982523,
#  664273150,
#  662438144,
#  686555395,
#  685768967,
#  691536139,
#  654311692,
#  660078861,
#  693109011,
#  660603160,
#  665583898,
#  681574688,
#  691798304,
#  674496805,
#  690487589,
#  688390442,
#  671351087,
#  675545394,
#  674758963,
#  674496824,
#  664011065,
#  665583929,
#  693109048,
#  687341885,
#  665583937,
#  685769030,
#  664011079,
#  657981768,
#  685769031,
#  662438221,
#  670302542,
#  660078928,
#  656933201,
#  657719639,
#  681574744,
#  665059673,
#  676069721,
#  653263196,
#  674496862,
#  691798367,
#  674496864,
#  686555489,
#  678166885,
#  674759017,
#  685769068,
#  655098223,
#  665583983,
#  684982639,
#  662438265,
#  689963388,
#  676856189,
#  657981824,
#  686555521,
#  663748995,
#  665846149,
#  684982662,
#  667156875,
#  657195404,
#  674759055,
#  665584019,
#  684982678,
#  665584025,
#  658506138,
#  673448345,
#  691798427,
#  673972638,
#  665584031,
#  662438306,
#  664797606,
#  657981863,
#  686555561,
#  680264112,
#  657195445,
#  688652725,
#  666370490,
#  672924091,
#  674759102,
#  673972671,
#  680001993,
#  679477706,
#  679739851,
#  674496972,
#  659554766,
#  665584079,
#  689439183,
#  658506193,
#  683934163,
#  652739031,
#  680526295,
#  670826972,
#  654574045,
#  653001182,
#  664011231,
#  666370527,
#  686031327,
#  664011238,
#  674759149,
#  685769199,
#  657457648,
#  664797682,
#  675807731,
#  686555635,
#  685769205,
#  687342068,
#  653525498,
#  670827004,
#  667419133,
#  655622658,
#  659554824,
#  673448463,
#  686555664,
#  690487828,
#  681574936,
#  685244956,
#  687342109,
#  685769248,
#  674759204,
#  688390700,
#  676069936,
#  662700597,
#  684982838,
#  685769270,
#  670302776,
#  665584185,
#  687079991,
#  687342136,
#  691798585,
#  665584189,
#  691798586,
#  678691392,
#  657195587,
#  674759237,
#  659817030,
#  660603464,
#  685769291,
#  665846349,
#  656409170,
#  660603475,
#  684982870,
#  667943511,
#  685769305,
#  686555737,
#  681575003,
#  686555738,
#  687342177,
#  662438499,
#  690487909,
#  683672166,
#  681312872,
#  667419243,
#  674759275,
#  683147889,
#  662438518,
#  654312056,
#  667157112,
#  657982075,
#  665584251,
#  674497150,
#  657457795,
#  654049932,
#  684982925,
#  676594318,
#  653263506,
#  671351443,
#  688652947,
#  658506389,
#  686555797,
#  669254295,
#  662962840,
#  671351448,
#  662438559,
#  657982112,
#  665059999,
#  658768546,
#  660865699,
#  665584289,
#  667419301,
#  680002210,
#  685769380,
#  686555816,
#  662176427,
#  679215790,
#  655098544,
#  661390002,
#  662438578,
#  670565050,
#  674497210,
#  666108605,
#  684982974,
#  661652159,
#  668730047,
#  692060861,
#  660865731,
#  684982979,
#  683934405,
#  691798723,
#  687080136,
#  664797900,
#  664535758,
#  662438609,
#  673448659,
#  687342292,
#  674497239,
#  678691545,
#  678953689,
#  691536603,
#  667157213,
#  664797918,
#  665322212,
#  674497254,
#  657982183,
#  662438631,
#  657982187,
#  657982188,
#  684983020,
#  662438641,
#  655885045,
#  662438651,
#  664273659,
#  657457917,
#  675021564,
#  678167295,
#  658768640,
#  671089408,
#  685769472,
#  680264451,
#  691536640,
#  692847359,
#  684983046,
#  652215048,
#  685769480,
#  669254410,
#  674759440,
#  655622929,
#  657195793,
#  675021584,
#  691536657,
#  655098645,
#  681575189,
#  658506520,
#  683148057,
#  690225947,
#  660341532,
#  665584413,
#  686555933,
#  685769507,
#  675808042,
#  657457964,
#  656409395,
#  691798839,
#  679740216,
#  664273721,
#  687342392,
#  681575228,
#  667681604,
#  689701700,
#  653263689,
#  667157322,
#  662438734,
#  665846606,
#  682099534,
#  686818128,
#  691798863,
#  662438742,
#  666633048,
#  657458011,
#  664798043,
#  668205916,
#  681575263,
#  655885157,
#  677380965,
#  683934566,
#  683148136,
#  687342438,
#  693109609,
#  693371751,
#  665584495,
#  658506612,
#  686556021,
#  661914488,
#  677643129,
#  669254524,
#  684983164,
#  657195902,
#  686556034,
#  691012483,
#  655098756,
#  664798084,
#  662438790,
#  683410311,
#  680526731,
#  673448844,
#  669254542,
#  668205967,
#  681575310,
#  674497426,
#  668205971,
#  673448859,
#  661914528,
#  674235297,
#  685769635,
#  663225253,
#  658506663,
#  666370983,
#  652739499,
#  687342509,
#  689439662,
#  668205999,
#  674759600,
#  677381039,
#  684983215,
#  674235315,
#  686556084,
#  668206008,
#  669254584,
#  671351739,
#  686556092,
#  657195965,
#  684721088,
#  674497473,
#  655360967,
#  660079560,
#  684983241,
#  689963976,
#  672924621,
#  674759631,
#  673186768,
#  654312401,
#  656147409,
#  673448915,
#  662438868,
#  681575376,
#  687342546,
#  653788119,
#  686556128,
#  674497506,
#  677905379,
#  657982436,
#  684983271,
#  687342568,
#  657982442,
#  665060330,
#  685769707,
#  662438893,
#  691274730,
#  668206068,
#  675546100,
#  653001718,
#  655098872,
#  681575416,
#  690226169,
#  674759675,
#  660603900,
#  690488317,
#  675283969,
#  659031042,
#  680002561,
#  674497540,
#  681051140,
#  659293190,
#  691536898,
#  666371080,
#  662438922,
#  686556170,
#  686556174,
#  680002582,
#  668206109,
#  681575455,
#  652215330,
#  684983331,
#  690226214,
#  656933927,
#  665584680,
#  667419687,
#  686031919,
#  687342647,
#  679740477,
#  687342654,
#  679478336,
#  654312514,
#  662438979,
#  675546178,
#  662438982,
#  690750534,
#  690488392,
#  667157577,
#  691799126,
#  665584728,
#  666633304,
#  691012703,
#  662439008,
#  660341857,
#  657196130,
#  657982563,
#  686556259,
#  689439845,
#  692061283,
#  655098984,
#  662439019,
#  662701165,
#  690226287,
#  668992624,
#  677381234,
#  653788276,
#  662439032,
#  680789113,
#  681313402,
#  687342713,
#  690226298,
#  667157629,
#  660604031,
#  674759810,
#  665060484,
#  659031175,
#  664011911,
#  665584776,
#  675021963,
#  668730508,
#  684983437,
#  687867022,
#  666633359,
#  687080592,
#  655099029,
#  657982613,
#  691799191,
#  685769880,
#  667157658,
#  674497693,
#  682362015,
#  690226338,
#  662439075,
#  671351973,
#  662439078,
#  672138406,
#  665846953,
#  688129195,
#  662439085,
#  668468397,
#  675808433,
#  664798389,
#  670827701,
#  652739767,
#  693109948,
#  669254845,
#  687342784,
#  679740612,
#  686556357,
#  656409798,
#  667157707,
#  663749837,
#  686556366,
#  662701263,
#  690750673,
#  659817684,
#  677381338,
#  669254875,
#  662439132,
#  665584861,
#  674497756,
#  685769960,
#  691799272,
#  684983530,
#  655885547,
#  657982700,
#  677119213,
#  690226416,
#  662439159,
#  657982712,
#  651953404,
#  669254909,
#  686556412,
#  691275007,
#  682099968,
#  687342852,
#  690488580,
#  681575686,
#  691799302,
#  692585736,
#  671614222,
#  687342863,
#  673187088,
#  691799312,
#  688915730,
#  655099157,
#  662439192,
#  682362136,
#  655361309,
#  677119266,
#  685770018,
#  685770019,
#  690226467,
#  682362150,
#  690226471,
#  656934184,
#  662439210,
#  655099179,
#  667944236,
#  687080753,
#  662701363,
#  671089984,
#  678692161,
#  661652802,
#  670303558,
#  664798536,
#  667682127,
#  685770070,
#  686556502,
#  687867224,
#  653788505,
#  666895706,
#  684983641,
#  655099230,
#  657982814,
#  692585823,
#  671090017,
#  690226530,
#  691799393,
#  656934246,
#  664798569,
#  657458538,
#  661652842,
#  684459373,
#  676070767,
#  659817842,
#  669255026,
#  664798580,
#  671352180,
#  673973622,
#  657982840,
#  680527227,
#  664012158,
#  661652867,
#  683410819,
#  682362245,
#  660604303,
#  667157904,
#  669255057,
#  684459411,
#  666633620,
#  657196439,
#  674235801,
#  683935130,
#  691799453,
#  662701471,
#  667157920,
#  687080865,
#  657458594,
#  664012196,
#  667420070,
#  677381543,
#  684983722,
#  679478700,
#  651691437,
#  676857262,
#  657982895,
#  683410863,
#  664798641,
#  667682228,
#  660080057,
#  675022267,
#  674497985,
#  668992962,
#  687343043,
#  655099336,
#  664274376,
#  683673033,
#  667944395,
#  657982926,
#  683935183,
#  667420115,
#  684983763,
#  664798677,
#  671876566,
#  687343062,
#  688129493,
#  658507225,
#  662439385,
#  659031515,
#  682624473,
#  651953629,
#  686556640,
#  661128675,
#  662439395,
#  687343079,
#  652477930,
#  665060843,
#  666895852,
#  664012271,
#  655099382,
#  669255159,
#  692848119,
#  661915131,
#  665847296,
#  681051649,
#  690226690,
#  653264388,
#  685770246,
#  686556679,
#  678168073,
#  687343114,
#  658507275,
#  661915149,
#  664798737,
#  667682325,
#  682886678,
#  655099415,
#  669255192,
#  673449496,
#  657983002,
#  685508123,
#  663225887,
#  673187363,
#  665847332,
#  682624547,
#  657196582,
#  651691559,
#  664798760,
#  658507307,
#  683410987,
#  653788717,
#  681575982,
#  662439472,
#  684983858,
#  677381683,
#  685770293,
#  669255222,
#  674498102,
#  674498104,
#  662439482,
#  685770299,
#  691013182,
#  668468805,
#  654575175,
#  651691594,
#  660080210,
#  689440343,
#  657458777,
#  658507355,
#  651953756,
#  678954587,
#  684983900,
#  672925285,
#  681576037,
#  683411047,
#  669517416,
#  674498152,
#  689964650,
#  662439532,
#  657983087,
#  691275375,
#  661653105,
#  686556785,
#  664536697,
#  664798844,
#  675022462,
#  681576063,
#  692586116,
#  659555980,
#  664798863,
#  665061007,
#  667158161,
#  657458836,
#  660342421,
#  654313110,
#  677381782,
#  684721815,
#  686556822,
#  658507425,
#  655099555,
#  667682467,
#  674498212,
#  687343274,
#  681576107,
#  654837424,
#  669255346,
#  686556850,
#  658769590,
#  658507448,
#  651691705,
#  664798906,
#  686556859,
#  671876797,
#  687343295,
#  686556866,
#  683411139,
#  657983172,
#  657458885,
#  681576132,
#  689702600,
#  671090383,
#  672663249,
#  674498258,
#  661915347,
#  660866772,
#  686556882,
#  661653208,
#  669517528,
#  651691738,
#  657458907,
#  655099614,
#  662963934,
#  673187552,
#  671614691,
#  675808997,
#  685770471,
#  693372649,
#  664012522,
#  687343338,
#  691799786,
#  664012535,
#  653002489,
#  655099641,
#  658507514,
#  663750395,
#  666896121,
#  688129786,
#  651691777,
#  656148228,
#  657458951,
#  671090443,
#  677381900,
#  652478222,
#  674498319,
#  656148240,
#  691799822,
#  651691799,
#  681576216,
#  664799002,
#  657983260,
#  657983268,
#  656148263,
#  685770538,
#  667158316,
#  667682605,
#  652478254,
#  664799022,
#  683411247,
#  655099697,
#  683935539,
#  687343418,
#  655886139,
#  691799867,
#  651691841,
#  670304066,
#  656148291,
#  657459011,
#  653002565,
#  690227012,
#  686032711,
#  664799054,
#  653264719,
#  691799886,
#  689702740,
#  662701909,
#  683411286,
#  690227031,
#  678954842,
#  679216990,
#  674498399,
#  664274786,
#  681576291,
#  655099756,
#  690489196,
#  656934767,
#  691799920,
#  654313329,
#  686819190,
#  655624055,
#  654575481,
#  662439801,
#  666896249,
#  660866940,
#  662439804,
#  667158395,
#  677382017,
#  680003457,
#  686557057,
#  690489217,
#  657983366,
#  669255560,
#  657459087,
#  687343505,
#  658245523,
#  671352724,
#  657983381,
#  684197784,
#  674498457,
#  673974170,
#  667682715,
#  692586398,
#  667158432,
#  683149216,
#  669255597,
#  674760625,
#  690227121,
#  686557108,
#  671877045,
#  683149239,
#  662439869,
#  681314240,
#  681576385,
#  662964162,
#  668993480,
#  682624974,
#  657197007,
#  691275737,
#  662439900,
#  691800031,
#  676595680,
#  668731363,
#  660342756,
#  654313445,
#  657983462,
#  691013603,
#  674498539,
#  653527020,
#  674760685,
#  656148462,
#  665585649,
#  681576435,
#  681576441,
#  667158523,
#  675547133,
#  655099908,
#  655099913,
#  667944971,
#  655886349,
#  657983502,
#  672401422,
#  674236430,
#  687343635,
#  682625046,
#  673187866,
#  681576475,
#  665585699,
#  667158563,
#  681314341,
#  659032102,
#  669255719,
#  657721384,
#  693110828,
#  688130095,
#  666896432,
#  671352880,
#  687343664,
#  665585715,
#  684984378,
#  673450045,
#  657983553,
#  662440002,
#  660605000,
#  691800137,
#  671877195,
#  688392268,
#  677382221,
#  682625101,
#  689440847,
#  684984400,
#  667420755,
#  673974362,
#  664537182,
#  661391455,
#  664799336,
#  691800168,
#  684984427,
#  674236529,
#  680265850,
#  656672894,
#  657459327,
#  661653637,
#  651692168,
#  654837896,
#  665585800,
#  688392329,
#  667158671,
#  660342928,
#  691013777,
#  670304403,
#  660080791,
#  684198039,
#  ...}
